# %%
import os
import csv
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
# FUNCTIONS
def compute_CI(conf_level,values):
    """
    Compute 95% confidence interval for the 
    mean subj bias in a given experiment
    """
    X = np.mean(values)
    SD = np.std(values)
    n = len(values)
    t = stats.t.ppf(conf_level,n-1)
    MoE = t * (SD / np.sqrt(n))
    left = X - MoE
    right = X + MoE
    return [X,SD,MoE,(left,right)]

def compute_verb_subj_bias(df):
    """
    Compute the mean subj bias for female and male referents
    """
    verbs = df['verb'].values
    verb_subj_bias = (df['subj_ref_female_subj'].values + df['subj_ref_male_subj'].values)/2 
    data = pd.DataFrame(data={'verb':verbs,'subj_bias':verb_subj_bias})
    return data  

def compute_CI_for_experiments(dirpath,conf_level):
    """
    Compute confidence intervals for experiments
    associated with a specific model
    """
    model_exp_results = []
    for file in sorted(os.listdir(dirpath)):
        filepath = os.path.join(dirpath,file)
        # create dataframe
        df = pd.read_csv(filepath)
        # compute overall subj bias for each verb
        verb_bias = compute_verb_subj_bias(df)
        vals = verb_bias['subj_bias'].values
        # compute 95% confidence interval
        results = compute_CI(0.95,vals)
        # experiment results
        exp_type = os.path.splitext(file)[0]
        exp_results = {exp_type : results}
        model_exp_results.append(exp_results)
    return model_exp_results

def write_results_to_file(filepath,model_results):
    with open(filepath,'w') as csvfile:
        writer = csv.writer(csvfile,delimiter=',')
        writer.writerow(["verb_exp_type","mean","std_dev","margin_error","conf_interval"])  
        for verb_exp in model_results:
            for verb_type, results in verb_exp.items():
                row = [verb_type] + results
                writer.writerow(row)

# %% [markdown]
# ###  Statistics for GPT-2 Experiments

# %%
gpt2_exp_path = "results/gpt2/summary"
gpt2_exp_stats = "results/gpt2_exp_stats.csv"

# %%
gpt2_exp_CI_results = compute_CI_for_experiments(gpt2_exp_path,0.95)
write_results_to_file(gpt2_exp_stats,gpt2_exp_CI_results)

# %%
gpt2_stats = pd.read_csv(gpt2_exp_stats)
gpt2_stats
# Out:
#                            verb_exp_type      mean   std_dev  margin_error  \
# 0                        IC1-connective1  0.630797  0.051071      0.019746
# 1                        IC1-connective2  0.306063  0.059007      0.022815
# 2                           IC1-noprompt  0.594840  0.051457      0.019896
# 3                        IC2-connective1  0.419262  0.121214      0.046867
# 4                        IC2-connective2  0.470103  0.174534      0.067483
# 5                           IC2-noprompt  0.660898  0.046357      0.017924
# 6                     motion-connective1  0.649254  0.036205      0.014845
# 7                     motion-connective2  0.461234  0.043116      0.017679
# 8                        motion-noprompt  0.630973  0.022950      0.009410
# 9   transofposs_imperfective-connective1  0.561594  0.060944      0.024245
# 10  transofposs_imperfective-connective2  0.454702  0.071588      0.029353
# 11     transofposs_imperfective-noprompt  0.619844  0.044279      0.018749
# 12    transofposs_perfective-connective1  0.527322  0.067606      0.026895
# 13    transofposs_perfective-connective2  0.262832  0.070748      0.028145
# 14       transofposs_perfective-noprompt  0.545315  0.079144      0.033513
#
#                                  conf_interval
# 0      (0.6110504685718969, 0.650543277449493)
# 1     (0.2832488164382517, 0.3288781155444841)
# 2     (0.5749445053188852, 0.6147361512234956)
# 3    (0.3723950305918708, 0.46612880149584474)
# 4    (0.40262050105412545, 0.5375860979951448)
# 5     (0.6429740410800016, 0.6788213417673872)
# 6     (0.6344087607571335, 0.6640987105358015)
# 7   (0.44355489008936005, 0.47891252219973396)
# 8     (0.6215626922598222, 0.6403827600053434)
# 9     (0.5373488745514946, 0.5858383438654452)
# 10   (0.42534937824905944, 0.4840555111899317)
# 11    (0.6010949215570824, 0.6385934139773217)
# 12    (0.5004274769660234, 0.5542174278686361)
# 13    (0.2346868008808999, 0.2909769789878606)
# 14    (0.5118026365840362, 0.5788279512637575)

# %% [markdown]
# ### Statistics for Transformer-XL Experiments

# %%
transfoxl_exp_path = "results/transfoxl/summary"
transfoxl_exp_stats = "results/transfoxl_exp_stats.csv"

# %%
transfoxl_exp_CI_results = compute_CI_for_experiments(transfoxl_exp_path,0.95)
write_results_to_file(transfoxl_exp_stats,transfoxl_exp_CI_results)

# %%
transfoxl_stats = pd.read_csv('results/transfoxl_exp_stats.csv')
transfoxl_stats
# Out:
#                            verb_exp_type      mean   std_dev  margin_error  \
# 0                        IC1-connective1  0.606976  0.073155      0.028285
# 1                        IC1-connective2  0.429707  0.053115      0.020537
# 2                           IC1-noprompt  0.505754  0.025950      0.010033
# 3                        IC2-connective1  0.454251  0.042123      0.016287
# 4                        IC2-connective2  0.495217  0.136698      0.052854
# 5                           IC2-noprompt  0.511348  0.046870      0.018122
# 6                     motion-connective1  0.613776  0.037700      0.015458
# 7                     motion-connective2  0.536081  0.038396      0.015743
# 8                        motion-noprompt  0.569162  0.029634      0.012151
# 9   transofposs_imperfective-connective1  0.560968  0.067763      0.026957
# 10  transofposs_imperfective-connective2  0.630108  0.071598      0.029357
# 11     transofposs_imperfective-noprompt  0.570090  0.033422      0.014152
# 12    transofposs_perfective-connective1  0.529317  0.075179      0.029908
# 13    transofposs_perfective-connective2  0.483459  0.095748      0.038091
# 14       transofposs_perfective-noprompt  0.522667  0.031579      0.013372
#
#                                 conf_interval
# 0     (0.578691167051509, 0.6352611693777989)
# 1   (0.4091707024877731, 0.45024407855242843)
# 2   (0.49572033317631276, 0.5157869107506348)
# 3    (0.4379645146669356, 0.4705375663696321)
# 4     (0.442363502105384, 0.5480712468146074)
# 5   (0.49322600914974335, 0.5294703494831738)
# 6    (0.5983177392891775, 0.6292335401968759)
# 7    (0.5203373040316047, 0.5518240487132043)
# 8    (0.5570116536869492, 0.5813128646216463)
# 9    (0.5340103838476119, 0.5879253062683295)
# 10   (0.6007504481517837, 0.6594648598480327)
# 11   (0.5559376501638582, 0.5842416907463812)
# 12   (0.4994094187744333, 0.5592253146146494)
# 13   (0.4453678689962855, 0.5215494860420709)
# 14     (0.509294992711754, 0.536038946084648)
