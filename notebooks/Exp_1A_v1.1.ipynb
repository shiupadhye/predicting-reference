# %% [markdown]
# Results for experiments conducted on a version of the stimuli with {"John","Mary"} as the subject/object pairs.

# %%
import pandas as pd
import numpy as np
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
#-------------- Helper Functions ------------- #
def compute_average(df, col,start_idx, end_idx):
    return np.mean(df[col].values[start_idx:end_idx])

# %% [markdown]
# ## Stimuli with implicit causality verbs (subject-biased)

# %% [markdown]
# #### Stimuli with no prompt

# %%
IC1_noprompt = pd.read_csv("../results/v1.1/exp1A_IC1.csv")
IC1_noprompt = IC1_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
IC1_noprompt
# Out:
#                      Stimuli        He       She
# 0      John aggravated Mary.  0.864451  0.135549
# 1          John amazed Mary.  0.409792  0.590208
# 2          John amused Mary.  0.631654  0.368346
# 3         John annoyed Mary.  0.655675  0.344325
# 4   John apologized to Mary.  0.828304  0.171696
# 5           John bored Mary.  0.506565  0.493435
# 6         John charmed Mary.  0.608304  0.391696
# 7    John confessed to Mary.  0.848104  0.151896
# 8        John deceived Mary.  0.392793  0.607207
# 9    John disappointed Mary.  0.825101  0.174899
# 10    John exasperated Mary.  0.688966  0.311034
# 11     John fascinated Mary.  0.249070  0.750930
# 12     John frightened Mary.  0.390360  0.609640
# 13     John humiliated Mary.  0.709307  0.290694
# 14     John infuriated Mary.  0.506107  0.493893
# 15       John inspires Mary.  0.239041  0.760959
# 16    John intimidates Mary.  0.277292  0.722708
# 17       John offended Mary.  0.611739  0.388261
# 18         John scares Mary.  0.312760  0.687240
# 19      John surprised Mary.  0.797637  0.202363
# 20     Mary aggravated John.  0.703212  0.296788
# 21         Mary amazed John.  0.733057  0.266943
# 22         Mary amused John.  0.640732  0.359269
# 23        Mary annoyed John.  0.625298  0.374702
# 24  Mary apologized to John.  0.547883  0.452117
# 25          Mary bored John.  0.693383  0.306617
# 26        Mary charmed John.  0.669154  0.330846
# 27   Mary confessed to John.  0.286564  0.713436
# 28       Mary deceived John.  0.659136  0.340864
# 29   Mary disappointed John.  0.629492  0.370508
# 30    Mary exasperated John.  0.643368  0.356632
# 31     Mary fascinated John.  0.567472  0.432528
# 32     Mary frightened John.  0.624663  0.375337
# 33     Mary humiliated John.  0.674119  0.325881
# 34     Mary infuriated John.  0.676728  0.323272
# 35       Mary inspires John.  0.744679  0.255321
# 36    Mary intimidates John.  0.698757  0.301243
# 37       Mary offended John.  0.685895  0.314105
# 38         Mary scares John.  0.644517  0.355483
# 39      Mary surprised John.  0.686522  0.313478

# %%
print("P('He'|subj=John)", compute_average(IC1_noprompt,"He",0,20))
print("P('She'|subj=John)", compute_average(IC1_noprompt,"She",0,20))
# Out:
# P('He'|subj=John) 0.5676509976387024
# P('She'|subj=John) 0.4323489986360073

# %%
print("P('She'|subj=Mary)",compute_average(IC1_noprompt,"She",20,40))
print("P('He'|subj=Mary)",compute_average(IC1_noprompt,"He",20,40))
# Out:
# P('She'|subj=Mary) 0.3582684800028801
# P('He'|subj=Mary) 0.6417315229773521

# %% [markdown]
# #### Prompt with connective: "because"

# %%
IC1_connective1 = pd.read_csv("../results/v1.1/exp1A_IC1_connective1.csv")
IC1_connective1 = IC1_connective1.sort_values(by='Stimuli').reset_index(drop=True)
IC1_connective1
# Out:
#                             Stimuli        he       she
# 0      John aggravated Mary because  0.776202  0.223798
# 1          John amazed Mary because  0.816251  0.183749
# 2          John amused Mary because  0.670574  0.329426
# 3         John annoyed Mary because  0.722764  0.277236
# 4   John apologized to Mary because  0.619711  0.380289
# 5           John bored Mary because  0.332729  0.667271
# 6         John charmed Mary because  0.681486  0.318514
# 7    John confessed to Mary because  0.983199  0.016800
# 8        John deceived Mary because  0.590993  0.409007
# 9    John disappointed Mary because  0.765433  0.234567
# 10    John exasperated Mary because  0.745405  0.254595
# 11     John fascinated Mary because  0.506325  0.493675
# 12     John frightened Mary because  0.511908  0.488092
# 13     John humiliated Mary because  0.578628  0.421372
# 14     John infuriated Mary because  0.539154  0.460846
# 15       John inspires Mary because  0.602619  0.397381
# 16    John intimidates Mary because  0.633032  0.366968
# 17       John offended Mary because  0.726970  0.273030
# 18         John scares Mary because  0.669943  0.330057
# 19      John surprised Mary because  0.953673  0.046327
# 20     Mary aggravated John because  0.138250  0.861750
# 21         Mary amazed John because  0.147165  0.852835
# 22         Mary amused John because  0.157166  0.842834
# 23        Mary annoyed John because  0.111185  0.888815
# 24  Mary apologized to John because  0.140207  0.859793
# 25          Mary bored John because  0.286127  0.713873
# 26        Mary charmed John because  0.175498  0.824502
# 27   Mary confessed to John because  0.010797  0.989203
# 28       Mary deceived John because  0.071821  0.928179
# 29   Mary disappointed John because  0.096165  0.903835
# 30    Mary exasperated John because  0.146409  0.853591
# 31     Mary fascinated John because  0.200123  0.799877
# 32     Mary frightened John because  0.225248  0.774752
# 33     Mary humiliated John because  0.233440  0.766560
# 34     Mary infuriated John because  0.155872  0.844128
# 35       Mary inspires John because  0.116362  0.883638
# 36    Mary intimidates John because  0.117788  0.882212
# 37       Mary offended John because  0.124111  0.875889
# 38         Mary scares John because  0.179961  0.820040
# 39      Mary surprised John because  0.111890  0.888110

# %%
print("P('he'|subj=John)=", compute_average(IC1_connective1,"he",0,20))
print("P('she'|subj=John)=", compute_average(IC1_connective1,"she",0,20))
# Out:
# P('he'|subj=John)= 0.6713499739766121
# P('she'|subj=John)= 0.3286500330083072

# %%
print("P('she'|subj=Mary)=",compute_average(IC1_connective1,"she",20,40))
print("P('he'|subj=Mary)=",compute_average(IC1_connective1,"he",20,40))
# Out:
# P('she'|subj=Mary)= 0.8527207762002945
# P('he'|subj=Mary)= 0.14727921560406684

# %% [markdown]
# #### Prompt with connective phrase: "and, as a result,"

# %%
IC1_connective2 = pd.read_csv("../results/v1.1/exp1A_IC1_connective2.csv")
IC1_connective2 = IC1_connective2.sort_values(by='Stimuli').reset_index(drop=True)
IC1_connective2
# Out:
#                                       Stimuli        he       she
# 0      John aggravated Mary and, as a result,  0.421059  0.578941
# 1          John amazed Mary and, as a result,  0.066730  0.933270
# 2          John amused Mary and, as a result,  0.122790  0.877210
# 3         John annoyed Mary and, as a result,  0.136596  0.863404
# 4   John apologized to Mary and, as a result,  0.276368  0.723632
# 5           John bored Mary and, as a result,  0.211808  0.788192
# 6         John charmed Mary and, as a result,  0.265248  0.734752
# 7    John confessed to Mary and, as a result,  0.281753  0.718247
# 8        John deceived Mary and, as a result,  0.092626  0.907374
# 9    John disappointed Mary and, as a result,  0.251715  0.748285
# 10    John exasperated Mary and, as a result,  0.117657  0.882343
# 11     John fascinated Mary and, as a result,  0.118060  0.881940
# 12     John frightened Mary and, as a result,  0.119507  0.880493
# 13     John humiliated Mary and, as a result,  0.256069  0.743931
# 14     John infuriated Mary and, as a result,  0.107694  0.892306
# 15       John inspires Mary and, as a result,  0.061003  0.938996
# 16    John intimidates Mary and, as a result,  0.035051  0.964949
# 17       John offended Mary and, as a result,  0.127999  0.872001
# 18         John scares Mary and, as a result,  0.070950  0.929050
# 19      John surprised Mary and, as a result,  0.128446  0.871554
# 20     Mary aggravated John and, as a result,  0.417685  0.582315
# 21         Mary amazed John and, as a result,  0.278039  0.721961
# 22         Mary amused John and, as a result,  0.261071  0.738929
# 23        Mary annoyed John and, as a result,  0.181201  0.818799
# 24  Mary apologized to John and, as a result,  0.457570  0.542430
# 25          Mary bored John and, as a result,  0.219954  0.780046
# 26        Mary charmed John and, as a result,  0.369547  0.630453
# 27   Mary confessed to John and, as a result,  0.270738  0.729262
# 28       Mary deceived John and, as a result,  0.295581  0.704419
# 29   Mary disappointed John and, as a result,  0.173799  0.826201
# 30    Mary exasperated John and, as a result,  0.208291  0.791709
# 31     Mary fascinated John and, as a result,  0.243584  0.756416
# 32     Mary frightened John and, as a result,  0.317178  0.682822
# 33     Mary humiliated John and, as a result,  0.307071  0.692929
# 34     Mary infuriated John and, as a result,  0.179970  0.820030
# 35       Mary inspires John and, as a result,  0.394974  0.605027
# 36    Mary intimidates John and, as a result,  0.307445  0.692555
# 37       Mary offended John and, as a result,  0.130749  0.869251
# 38         Mary scares John and, as a result,  0.347243  0.652757
# 39      Mary surprised John and, as a result,  0.231309  0.768691

# %%
print("P('he'|subj=John)=", compute_average(IC1_connective2,"he",0,20))
print("P('she'|subj=John)=", compute_average(IC1_connective2,"she",0,20))
# Out:
# P('he'|subj=John)= 0.16345655657351016
# P('she'|subj=John)= 0.8365434348583222

# %%
print("P('she'|subj=Mary)=",compute_average(IC1_connective2,"she",20,40))
print("P('he'|subj=Mary)=",compute_average(IC1_connective2,"he",20,40))
# Out:
# P('she'|subj=Mary)= 0.7203500539064407
# P('he'|subj=Mary)= 0.2796499714255333

# %% [markdown]
# ## Stimuli with implicit causality verbs (Object-Biased)

# %% [markdown]
# #### Stimuli with no prompt

# %%
IC2_noprompt = pd.read_csv("../results/v1.1/exp1A_IC2.csv")
IC2_noprompt = IC2_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
IC2_noprompt
# Out:
#                      Stimuli        He       She
# 0        John assisted Mary.  0.385432  0.614568
# 1          John blames Mary.  0.785164  0.214836
# 2       John comforted Mary.  0.705945  0.294054
# 3   John congratulated Mary.  0.294936  0.705064
# 4       John corrected Mary.  0.730922  0.269078
# 5         John detests Mary.  0.841376  0.158624
# 6          John envies Mary.  0.841186  0.158814
# 7           John fears Mary.  0.737684  0.262316
# 8           John hates Mary.  0.843192  0.156808
# 9          John helped Mary.  0.243740  0.756260
# 10         John mocked Mary.  0.461088  0.538912
# 11        John noticed Mary.  0.801935  0.198065
# 12       John pacified Mary.  0.712120  0.287880
# 13        John praised Mary.  0.584511  0.415489
# 14     John reproached Mary.  0.187464  0.812536
# 15        John scolded Mary.  0.217312  0.782688
# 16      John stared at Mary.  0.843423  0.156577
# 17        John thanked Mary.  0.484699  0.515301
# 18         John trusts Mary.  0.478412  0.521588
# 19         John values Mary.  0.859460  0.140540
# 20       Mary assisted John.  0.603964  0.396036
# 21         Mary blames John.  0.606439  0.393561
# 22      Mary comforted John.  0.620737  0.379263
# 23  Mary congratulated John.  0.725636  0.274364
# 24      Mary corrected John.  0.639568  0.360432
# 25        Mary detests John.  0.498703  0.501297
# 26         Mary envies John.  0.598943  0.401057
# 27          Mary fears John.  0.675534  0.324466
# 28          Mary hates John.  0.502471  0.497529
# 29         Mary helped John.  0.566894  0.433106
# 30         Mary mocked John.  0.770841  0.229159
# 31        Mary noticed John.  0.737999  0.262001
# 32       Mary pacified John.  0.693892  0.306108
# 33        Mary praised John.  0.719312  0.280688
# 34     Mary reproached John.  0.685552  0.314448
# 35        Mary scolded John.  0.648271  0.351729
# 36      Mary stared at John.  0.462384  0.537616
# 37        Mary thanked John.  0.691594  0.308406
# 38         Mary trusts John.  0.748867  0.251133
# 39         Mary values John.  0.672431  0.327569

# %%
print("P('He'|subj=John)", compute_average(IC2_noprompt,"He",0,20))
print("P('She'|subj=John)", compute_average(IC2_noprompt,"She",0,20))
# Out:
# P('He'|subj=John) 0.6020000904798508
# P('She'|subj=John) 0.3979999214410782

# %%
print("P('She'|subj=Mary)",compute_average(IC2_noprompt,"She",20,40))
print("P('He'|subj=Mary)",compute_average(IC2_noprompt,"He",20,40))
# Out:
# P('She'|subj=Mary) 0.3564982660114765
# P('He'|subj=Mary) 0.6435017362236977

# %% [markdown]
# #### Stimulus with connective: "because"

# %%
IC2_connective1 = pd.read_csv("../results/v1.1/exp1A_IC2_connective1.csv")
IC2_connective1 = IC2_connective1.sort_values(by='Stimuli').reset_index(drop=True)
IC2_connective1
# Out:
#                             Stimuli        he       she
# 0        John assisted Mary because  0.365662  0.634338
# 1          John blames Mary because  0.273666  0.726334
# 2       John comforted Mary because  0.396711  0.603290
# 3   John congratulated Mary because  0.315060  0.684940
# 4       John corrected Mary because  0.531462  0.468538
# 5         John detests Mary because  0.268799  0.731201
# 6          John envies Mary because  0.306352  0.693648
# 7           John fears Mary because  0.401654  0.598346
# 8           John hates Mary because  0.237705  0.762295
# 9          John helped Mary because  0.334519  0.665481
# 10         John mocked Mary because  0.374062  0.625938
# 11        John noticed Mary because  0.343261  0.656739
# 12       John pacified Mary because  0.460850  0.539150
# 13        John praised Mary because  0.277721  0.722279
# 14     John reproached Mary because  0.197283  0.802718
# 15        John scolded Mary because  0.231734  0.768266
# 16      John stared at Mary because  0.428608  0.571392
# 17        John thanked Mary because  0.311412  0.688588
# 18         John trusts Mary because  0.358996  0.641004
# 19         John values Mary because  0.305755  0.694245
# 20       Mary assisted John because  0.098762  0.901238
# 21         Mary blames John because  0.293555  0.706445
# 22      Mary comforted John because  0.388071  0.611929
# 23  Mary congratulated John because  0.383159  0.616841
# 24      Mary corrected John because  0.108691  0.891309
# 25        Mary detests John because  0.265388  0.734612
# 26         Mary envies John because  0.272762  0.727238
# 27          Mary fears John because  0.243558  0.756442
# 28          Mary hates John because  0.368440  0.631560
# 29         Mary helped John because  0.139474  0.860526
# 30         Mary mocked John because  0.265706  0.734294
# 31        Mary noticed John because  0.371879  0.628121
# 32       Mary pacified John because  0.211984  0.788016
# 33        Mary praised John because  0.384313  0.615687
# 34     Mary reproached John because  0.412128  0.587872
# 35        Mary scolded John because  0.371264  0.628736
# 36      Mary stared at John because  0.383800  0.616200
# 37        Mary thanked John because  0.261256  0.738744
# 38         Mary trusts John because  0.363742  0.636258
# 39         Mary values John because  0.205997  0.794003

# %%
print("P('he'|subj=John)", compute_average(IC2_connective1,"he",0,20))
print("P('she'|subj=John)", compute_average(IC2_connective1,"she",0,20))
# Out:
# P('he'|subj=John) 0.33606345802545545
# P('she'|subj=John) 0.6639365509152413

# %%
print("P('she'|subj=Mary)",compute_average(IC2_connective1,"she",20,40))
print("P('he'|subj=Mary)",compute_average(IC2_connective1,"he",20,40))
# Out:
# P('she'|subj=Mary) 0.7103036016225814
# P('he'|subj=Mary) 0.2896963909268379

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
IC2_connective2 = pd.read_csv("../results/v1.1/exp1A_IC2_connective2.csv")
IC2_connective2 = IC2_connective2.sort_values(by='Stimuli').reset_index(drop=True)
IC2_connective2
# Out:
#                                       Stimuli        he       she
# 0        John assisted Mary and, as a result,  0.220935  0.779065
# 1          John blames Mary and, as a result,  0.380076  0.619924
# 2       John comforted Mary and, as a result,  0.182596  0.817404
# 3   John congratulated Mary and, as a result,  0.137797  0.862203
# 4       John corrected Mary and, as a result,  0.675296  0.324704
# 5         John detests Mary and, as a result,  0.751769  0.248231
# 6          John envies Mary and, as a result,  0.567083  0.432917
# 7           John fears Mary and, as a result,  0.697363  0.302637
# 8           John hates Mary and, as a result,  0.700052  0.299948
# 9          John helped Mary and, as a result,  0.232318  0.767682
# 10         John mocked Mary and, as a result,  0.439585  0.560415
# 11        John noticed Mary and, as a result,  0.559289  0.440711
# 12       John pacified Mary and, as a result,  0.312073  0.687927
# 13        John praised Mary and, as a result,  0.271334  0.728666
# 14     John reproached Mary and, as a result,  0.188279  0.811721
# 15        John scolded Mary and, as a result,  0.213924  0.786076
# 16      John stared at Mary and, as a result,  0.322854  0.677146
# 17        John thanked Mary and, as a result,  0.288932  0.711068
# 18         John trusts Mary and, as a result,  0.217090  0.782910
# 19         John values Mary and, as a result,  0.606594  0.393406
# 20       Mary assisted John and, as a result,  0.355296  0.644704
# 21         Mary blames John and, as a result,  0.181472  0.818528
# 22      Mary comforted John and, as a result,  0.529152  0.470848
# 23  Mary congratulated John and, as a result,  0.568405  0.431595
# 24      Mary corrected John and, as a result,  0.470378  0.529622
# 25        Mary detests John and, as a result,  0.076995  0.923005
# 26         Mary envies John and, as a result,  0.088350  0.911650
# 27          Mary fears John and, as a result,  0.091572  0.908428
# 28          Mary hates John and, as a result,  0.125231  0.874769
# 29         Mary helped John and, as a result,  0.329001  0.670999
# 30         Mary mocked John and, as a result,  0.379970  0.620030
# 31        Mary noticed John and, as a result,  0.158112  0.841888
# 32       Mary pacified John and, as a result,  0.531295  0.468705
# 33        Mary praised John and, as a result,  0.549687  0.450313
# 34     Mary reproached John and, as a result,  0.399989  0.600011
# 35        Mary scolded John and, as a result,  0.340758  0.659242
# 36      Mary stared at John and, as a result,  0.323874  0.676126
# 37        Mary thanked John and, as a result,  0.545306  0.454694
# 38         Mary trusts John and, as a result,  0.304115  0.695885
# 39         Mary values John and, as a result,  0.176941  0.823059

# %%
print("P('He'|subj=John)", compute_average(IC2_connective2,"he",0,20))
print("P('She'|subj=John)", compute_average(IC2_connective2,"she",0,20))
# Out:
# P('He'|subj=John) 0.39826191067695615
# P('She'|subj=John) 0.6017380863428116

# %%
print("P('He'|subj=Mary)",compute_average(IC2_connective2,"he",20,40))
print("P('She'|subj=Mary)",compute_average(IC2_connective2,"she",20,40))
# Out:
# P('He'|subj=Mary) 0.3262948885560036
# P('She'|subj=Mary) 0.6737051159143448

# %% [markdown]
# ## Stimuli with motion verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
motion_noprompt = pd.read_csv("../results/v1.1/exp1A_motion.csv")
motion_noprompt = motion_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
motion_noprompt
# Out:
#                  Stimuli        He       She
# 0    John drove to Mary.  0.833962  0.166038
# 1     John flew to Mary.  0.827629  0.172371
# 2   John jogged to Mary.  0.840087  0.159913
# 3      John ran to Mary.  0.843705  0.156295
# 4     John swam to Mary.  0.839035  0.160965
# 5   John walked to Mary.  0.842675  0.157325
# 6    Mary drove to John.  0.623303  0.376697
# 7     Mary flew to John.  0.630211  0.369789
# 8   Mary jogged to John.  0.514178  0.485822
# 9      Mary ran to John.  0.625690  0.374310
# 10    Mary swam to John.  0.494639  0.505361
# 11  Mary walked to John.  0.587846  0.412154

# %%
print("P('He'|subj=John)", compute_average(motion_noprompt,"He",0,6))
print("P('She'|subj=John)", compute_average(motion_noprompt,"She",0,6))
# Out:
# P('He'|subj=John) 0.8378488719463348
# P('She'|subj=John) 0.1621511479218801

# %%
print("P('He'|subj=Mary)",compute_average(motion_noprompt,"He",6,12))
print("P('She'|subj=Mary)",compute_average(motion_noprompt,"She",6,12))
# Out:
# P('He'|subj=Mary) 0.579311137398084
# P('She'|subj=Mary) 0.42068885763486225

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
motion_connective1 = pd.read_csv("../results/v1.1/exp1A_motion_connective1.csv")
motion_connective1 = motion_connective1.sort_values(by='Stimuli').reset_index(drop=True)
motion_connective1
# Out:
#                         Stimuli        he       she
# 0    John drove to Mary because  0.558130  0.441870
# 1     John flew to Mary because  0.564466  0.435534
# 2   John jogged to Mary because  0.530508  0.469492
# 3      John ran to Mary because  0.687738  0.312262
# 4     John swam to Mary because  0.734714  0.265286
# 5   John walked to Mary because  0.674654  0.325346
# 6    Mary drove to John because  0.049342  0.950658
# 7     Mary flew to John because  0.016550  0.983450
# 8   Mary jogged to John because  0.051028  0.948972
# 9      Mary ran to John because  0.049478  0.950522
# 10    Mary swam to John because  0.015549  0.984451
# 11  Mary walked to John because  0.031018  0.968982

# %%
print("P('he'|subj=John)", compute_average(motion_connective1,"he",0,6))
print("P('she'|subj=John)", compute_average(motion_connective1,"she",0,6))
# Out:
# P('he'|subj=John) 0.62503515680631
# P('she'|subj=John) 0.37496482332547504

# %%
print("P('she'|subj=Mary)",compute_average(motion_connective1,"she",6,12))
print("P('he'|subj=Mary)",compute_average(motion_connective1,"he",6,12))
# Out:
# P('she'|subj=Mary) 0.9645058612028757
# P('he'|subj=Mary) 0.035494141125430666

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
motion_connective2 = pd.read_csv("../results/v1.1/exp1A_motion_connective2.csv")
motion_connective2 = motion_connective2.sort_values(by='Stimuli').reset_index(drop=True)
motion_connective2
# Out:
#                                   Stimuli        he       she
# 0    John drove to Mary and, as a result,  0.323613  0.676387
# 1     John flew to Mary and, as a result,  0.466129  0.533871
# 2   John jogged to Mary and, as a result,  0.421595  0.578405
# 3      John ran to Mary and, as a result,  0.218409  0.781591
# 4     John swam to Mary and, as a result,  0.452452  0.547548
# 5   John walked to Mary and, as a result,  0.295552  0.704448
# 6    Mary drove to John and, as a result,  0.265739  0.734261
# 7     Mary flew to John and, as a result,  0.234169  0.765831
# 8   Mary jogged to John and, as a result,  0.333643  0.666357
# 9      Mary ran to John and, as a result,  0.379917  0.620083
# 10    Mary swam to John and, as a result,  0.222346  0.777654
# 11  Mary walked to John and, as a result,  0.275503  0.724497

# %%
print("P('he'|subj=John)", compute_average(motion_connective2,"he",0,6))
print("P('she'|subj=John)", compute_average(motion_connective2,"she",0,6))
# Out:
# P('he'|subj=John) 0.3629583815733592
# P('she'|subj=John) 0.6370416184266409

# %%
print("P('she'|subj=Mary)",compute_average(motion_connective2,"she",6,12))
print("P('he'|subj=Mary)",compute_average(motion_connective2,"he",6,12))
# Out:
# P('she'|subj=Mary) 0.714780350526174
# P('he'|subj=Mary) 0.2852196569244067

# %% [markdown]
# ## Stimuli with transfer of possession verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
transofposs_noprompt = pd.read_csv("../results/v1.1/exp1A_transofposs.csv")
transofposs_noprompt = transofposs_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
transofposs_noprompt
# Out:
#                                Stimuli        He       She
# 0        John brought flowers to Mary.  0.833501  0.166499
# 1       John carried a banana to Mary.  0.849062  0.150938
# 2            John gave a book to Mary.  0.843754  0.156246
# 3          John handed a gift to Mary.  0.846995  0.153005
# 4   John kicked a soccer ball to Mary.  0.859350  0.140650
# 5        John mailed a letter to Mary.  0.844907  0.155093
# 6    John rolled a beach ball to Mary.  0.864549  0.135451
# 7        John threw a Frisbee to Mary.  0.854088  0.145912
# 8        Mary brought flowers to John.  0.596620  0.403380
# 9       Mary carried a banana to John.  0.547515  0.452485
# 10           Mary gave a book to John.  0.582484  0.417516
# 11         Mary handed a gift to John.  0.690337  0.309663
# 12  Mary kicked a soccer ball to John.  0.793057  0.206943
# 13       Mary mailed a letter to John.  0.693894  0.306106
# 14   Mary rolled a beach ball to John.  0.499744  0.500256
# 15       Mary threw a Frisbee to John.  0.746782  0.253218

# %%
print("P('He'|subj=John)", compute_average(transofposs_noprompt,"He",0,8))
print("P('She'|subj=John)", compute_average(transofposs_noprompt,"She",0,8))
# Out:
# P('He'|subj=John) 0.8495257422327995
# P('She'|subj=John) 0.15047425217926502

# %%
print("P('She'|subj=Mary)",compute_average(transofposs_noprompt,"She",8,16))
print("P('He'|subj=Mary)",compute_average(transofposs_noprompt,"He",8,16))
# Out:
# P('She'|subj=Mary) 0.3561958782374859
# P('He'|subj=Mary) 0.6438041105866432

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
transofposs_connective1 = pd.read_csv("../results/v1.1/exp1A_transofposs_connective1.csv")
transofposs_connective1 = transofposs_connective1.sort_values(by='Stimuli').reset_index(drop=True)
transofposs_connective1
# Out:
#                                       Stimuli        he       she
# 0        John brought flowers to Mary because  0.279155  0.720845
# 1       John carried a banana to Mary because  0.724666  0.275334
# 2            John gave a book to Mary because  0.490619  0.509381
# 3          John handed a gift to Mary because  0.516930  0.483070
# 4   John kicked a soccer ball to Mary because  0.288784  0.711216
# 5        John mailed a letter to Mary because  0.775705  0.224295
# 6    John rolled a beach ball to Mary because  0.472374  0.527626
# 7        John threw a Frisbee to Mary because  0.515916  0.484084
# 8        Mary brought flowers to John because  0.071238  0.928762
# 9       Mary carried a banana to John because  0.020250  0.979750
# 10           Mary gave a book to John because  0.040748  0.959252
# 11         Mary handed a gift to John because  0.060617  0.939383
# 12  Mary kicked a soccer ball to John because  0.195060  0.804940
# 13       Mary mailed a letter to John because  0.027944  0.972056
# 14   Mary rolled a beach ball to John because  0.045118  0.954882
# 15       Mary threw a Frisbee to John because  0.144071  0.855929

# %%
print("P('he'|subj=John)", compute_average(transofposs_connective1,"he",0,8))
print("P('she'|subj=John)", compute_average(transofposs_connective1,"she",0,8))
# Out:
# P('he'|subj=John) 0.5080187320709229
# P('she'|subj=John) 0.4919812735170126

# %%
print("P('she'|subj=Mary)",compute_average(transofposs_connective1,"she",8,16))
print("P('he'|subj=Mary)",compute_average(transofposs_connective1,"he",8,16))
# Out:
# P('she'|subj=Mary) 0.9243692755699158
# P('he'|subj=Mary) 0.07563070999458432

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
transofposs_connective2 = pd.read_csv("../results/v1.1/exp1A_transofposs_connective2.csv")
transofposs_connective2 = transofposs_connective2.sort_values(by='Stimuli').reset_index(drop=True)
transofposs_connective2
# Out:
#                                               Stimuli        he       she
# 0      John brought flowers to Mary and, as a result,  0.180651  0.819349
# 1     John carried a banana to Mary and, as a result,  0.539830  0.460170
# 2          John gave a book to Mary and, as a result,  0.183190  0.816810
# 3        John handed a gift to Mary and, as a result,  0.256938  0.743062
# 4   John kicked a soccer ball to Mary and, as a re...  0.403887  0.596113
# 5      John mailed a letter to Mary and, as a result,  0.174967  0.825033
# 6   John rolled a beach ball to Mary and, as a res...  0.427978  0.572022
# 7      John threw a Frisbee to Mary and, as a result,  0.253791  0.746209
# 8      Mary brought flowers to John and, as a result,  0.399195  0.600805
# 9     Mary carried a banana to John and, as a result,  0.320398  0.679602
# 10         Mary gave a book to John and, as a result,  0.427757  0.572243
# 11       Mary handed a gift to John and, as a result,  0.329673  0.670327
# 12  Mary kicked a soccer ball to John and, as a re...  0.374876  0.625124
# 13     Mary mailed a letter to John and, as a result,  0.284061  0.715939
# 14  Mary rolled a beach ball to John and, as a res...  0.337050  0.662950
# 15     Mary threw a Frisbee to John and, as a result,  0.401032  0.598968

# %%
print("P('he'|subj=John)", compute_average(transofposs_connective2,"he",0,8))
print("P('she'|subj=John)", compute_average(transofposs_connective2,"she",0,8))
# Out:
# P('he'|subj=John) 0.30265383794903755
# P('she'|subj=John) 0.6973461471498013

# %%
print("P('she'|subj=Mary)",compute_average(transofposs_connective2,"she",8,16))
print("P('he'|subj=Mary)",compute_average(transofposs_connective2,"he",8,16))
# Out:
# P('she'|subj=Mary) 0.6407447680830956
# P('he'|subj=Mary) 0.35925523936748505

# %% [markdown]
# ## Stimuli with perfective transfer of possession verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
asp_perfective_noprompt = pd.read_csv("../results/v1.1/exp1A_aspect_perfective.csv")
asp_perfective_noprompt = asp_perfective_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
asp_perfective_noprompt
# Out:
#                                     Stimuli        He       She
# 0    John brought a glass of water to Mary.  0.864286  0.135714
# 1              John carried a tray to Mary.  0.848823  0.151177
# 2        John delivered a subpoena to Mary.  0.855112  0.144888
# 3              John faxed a resume to Mary.  0.848725  0.151275
# 4             John flung a frisbee to Mary.  0.850487  0.149513
# 5   John forwarded a gossipy email to Mary.  0.851054  0.148946
# 6              John gave a sweater to Mary.  0.849673  0.150327
# 7               John handed a book to Mary.  0.840239  0.159761
# 8        John kicked a soccer ball to Mary.  0.859350  0.140650
# 9           John lobbed a football to Mary.  0.850745  0.149255
# 10            John mailed a letter to Mary.  0.844907  0.155093
# 11          John passed a sandwich to Mary.  0.856806  0.143194
# 12         John rolled a toy truck to Mary.  0.857563  0.142437
# 13           John sent a fruitcake to Mary.  0.832098  0.167902
# 14               John served chili to Mary.  0.848044  0.151956
# 15          John shipped a package to Mary.  0.829644  0.170356
# 16                John threw a hat to Mary.  0.850542  0.149458
# 17        John tossed a dish towel to Mary.  0.859717  0.140283
# 18      John transmitted a message to Mary.  0.839958  0.160042
# 19                John wired money to Mary.  0.849774  0.150226
# 20   Mary brought a glass of water to John.  0.487907  0.512093
# 21             Mary carried a tray to John.  0.609560  0.390440
# 22       Mary delivered a subpoena to John.  0.747448  0.252552
# 23             Mary faxed a resume to John.  0.620603  0.379397
# 24            Mary flung a frisbee to John.  0.789652  0.210348
# 25  Mary forwarded a gossipy email to John.  0.667294  0.332706
# 26             Mary gave a sweater to John.  0.493749  0.506251
# 27              Mary handed a book to John.  0.691805  0.308195
# 28       Mary kicked a soccer ball to John.  0.793057  0.206943
# 29          Mary lobbed a football to John.  0.788053  0.211947
# 30            Mary mailed a letter to John.  0.693894  0.306106
# 31          Mary passed a sandwich to John.  0.607943  0.392057
# 32         Mary rolled a toy truck to John.  0.453692  0.546308
# 33           Mary sent a fruitcake to John.  0.634048  0.365952
# 34               Mary served chili to John.  0.566092  0.433908
# 35          Mary shipped a package to John.  0.602908  0.397091
# 36                Mary threw a hat to John.  0.668004  0.331996
# 37        Mary tossed a dish towel to John.  0.615962  0.384038
# 38      Mary transmitted a message to John.  0.713353  0.286647
# 39                Mary wired money to John.  0.744028  0.255972

# %%
print("P('He'|subj=John)", compute_average(asp_perfective_noprompt,"He",0,19))
print("P('She'|subj=John)", compute_average(asp_perfective_noprompt,"She",0,19))
# Out:
# P('He'|subj=John) 0.8493564379842657
# P('She'|subj=John) 0.15064356044719093

# %%
print("P('She'|subj=Mary)",compute_average(asp_perfective_noprompt,"She",19,38))
print("P('He'|subj=Mary)",compute_average(asp_perfective_noprompt,"He",19,38))
# Out:
# P('She'|subj=Mary) 0.3483450248053199
# P('He'|subj=Mary) 0.651654955587889

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
asp_perfective_connective1 = pd.read_csv("../results/v1.1/exp1A_aspect_perfective_connective1.csv")
asp_perfective_connective1 = asp_perfective_connective1.sort_values(by='Stimuli').reset_index(drop=True)
asp_perfective_connective1
# Out:
#                                            Stimuli        he       she
# 0    John brought a glass of water to Mary because  0.343274  0.656726
# 1              John carried a tray to Mary because  0.652209  0.347791
# 2        John delivered a subpoena to Mary because  0.334349  0.665651
# 3             John flung a frisbee to Mary because  0.490681  0.509319
# 4   John forwarded a gossipy email to Mary because  0.560013  0.439987
# 5              John gave a sweater to Mary because  0.547375  0.452625
# 6               John handed a book to Mary because  0.326042  0.673958
# 7        John kicked a soccer ball to Mary because  0.288784  0.711216
# 8           John lobbed a football to Mary because  0.251896  0.748104
# 9             John mailed a letter to Mary because  0.775705  0.224295
# 10          John passed a sandwich to Mary because  0.567376  0.432624
# 11         John rolled a toy truck to Mary because  0.611643  0.388357
# 12           John sent a fruitcake to Mary because  0.483233  0.516767
# 13               John served chili to Mary because  0.598409  0.401591
# 14          John shipped a package to Mary because  0.372957  0.627043
# 15                John threw a hat to Mary because  0.490792  0.509208
# 16        John tossed a dish towel to Mary because  0.377080  0.622920
# 17      John transmitted a message to Mary because  0.710399  0.289601
# 18                John wired money to Mary because  0.515191  0.484809
# 19   Mary brought a glass of water to John because  0.070605  0.929395
# 20             Mary carried a tray to John because  0.034148  0.965852
# 21       Mary delivered a subpoena to John because  0.055348  0.944652
# 22            Mary flung a frisbee to John because  0.162489  0.837511
# 23  Mary forwarded a gossipy email to John because  0.048657  0.951343
# 24             Mary gave a sweater to John because  0.062451  0.937549
# 25              Mary handed a book to John because  0.074053  0.925947
# 26       Mary kicked a soccer ball to John because  0.195060  0.804940
# 27          Mary lobbed a football to John because  0.229388  0.770612
# 28            Mary mailed a letter to John because  0.027944  0.972056
# 29          Mary passed a sandwich to John because  0.053594  0.946406
# 30         Mary rolled a toy truck to John because  0.044201  0.955799
# 31           Mary sent a fruitcake to John because  0.047032  0.952968
# 32               Mary served chili to John because  0.018619  0.981381
# 33          Mary shipped a package to John because  0.027716  0.972284
# 34                Mary threw a hat to John because  0.121695  0.878305
# 35        Mary tossed a dish towel to John because  0.214028  0.785972
# 36      Mary transmitted a message to John because  0.021066  0.978934
# 37                Mary wired money to John because  0.208872  0.791128

# %%
print("P('he'|subj=John)", compute_average(asp_perfective_connective1,"he",0,19))
print("P('she'|subj=John)", compute_average(asp_perfective_connective1,"she",0,19))
# Out:
# P('he'|subj=John) 0.4893372372577065
# P('she'|subj=John) 0.5106627807805413

# %%
print("P('she'|subj=Mary)",compute_average(asp_perfective_connective1,"she",19,38))
print("P('he'|subj=Mary)",compute_average(asp_perfective_connective1,"he",19,38))
# Out:
# P('she'|subj=Mary) 0.9096333792335108
# P('he'|subj=Mary) 0.09036660802207495

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
asp_perfective_connective2 = pd.read_csv("../results/v1.1/exp1A_aspect_perfective_connective2.csv")
asp_perfective_connective2 = asp_perfective_connective2.sort_values(by='Stimuli').reset_index(drop=True)
asp_perfective_connective2
# Out:
#                                               Stimuli        he       she
# 0   John brought a glass of water to Mary and, as ...  0.218271  0.781729
# 1       John carried a tray to Mary and, as a result,  0.401353  0.598647
# 2   John delivered a subpoena to Mary and, as a re...  0.176694  0.823306
# 3      John flung a frisbee to Mary and, as a result,  0.224427  0.775573
# 4   John forwarded a gossipy email to Mary and, as...  0.140469  0.859531
# 5       John gave a sweater to Mary and, as a result,  0.220294  0.779706
# 6        John handed a book to Mary and, as a result,  0.168464  0.831536
# 7   John kicked a soccer ball to Mary and, as a re...  0.403887  0.596113
# 8    John lobbed a football to Mary and, as a result,  0.170162  0.829838
# 9      John mailed a letter to Mary and, as a result,  0.174967  0.825033
# 10   John passed a sandwich to Mary and, as a result,  0.218217  0.781783
# 11  John rolled a toy truck to Mary and, as a result,  0.455602  0.544398
# 12    John sent a fruitcake to Mary and, as a result,  0.078091  0.921909
# 13        John served chili to Mary and, as a result,  0.414798  0.585202
# 14   John shipped a package to Mary and, as a result,  0.206335  0.793665
# 15         John threw a hat to Mary and, as a result,  0.320216  0.679784
# 16  John tossed a dish towel to Mary and, as a res...  0.276342  0.723658
# 17  John transmitted a message to Mary and, as a r...  0.066881  0.933119
# 18         John wired money to Mary and, as a result,  0.070252  0.929748
# 19  Mary brought a glass of water to John and, as ...  0.311255  0.688745
# 20      Mary carried a tray to John and, as a result,  0.233739  0.766261
# 21  Mary delivered a subpoena to John and, as a re...  0.215750  0.784250
# 22     Mary flung a frisbee to John and, as a result,  0.415582  0.584418
# 23  Mary forwarded a gossipy email to John and, as...  0.218189  0.781811
# 24      Mary gave a sweater to John and, as a result,  0.460779  0.539221
# 25       Mary handed a book to John and, as a result,  0.347019  0.652981
# 26  Mary kicked a soccer ball to John and, as a re...  0.374876  0.625124
# 27   Mary lobbed a football to John and, as a result,  0.421419  0.578581
# 28     Mary mailed a letter to John and, as a result,  0.284061  0.715939
# 29   Mary passed a sandwich to John and, as a result,  0.240097  0.759903
# 30  Mary rolled a toy truck to John and, as a result,  0.337063  0.662937
# 31    Mary sent a fruitcake to John and, as a result,  0.315373  0.684627
# 32        Mary served chili to John and, as a result,  0.149606  0.850394
# 33   Mary shipped a package to John and, as a result,  0.209360  0.790640
# 34         Mary threw a hat to John and, as a result,  0.430294  0.569706
# 35  Mary tossed a dish towel to John and, as a res...  0.457256  0.542744
# 36  Mary transmitted a message to John and, as a r...  0.266532  0.733468
# 37         Mary wired money to John and, as a result,  0.422797  0.577203

# %%
print("P('he'|subj=John)", compute_average(asp_perfective_connective2,"he",0,19))
print("P('she'|subj=John)", compute_average(asp_perfective_connective2,"she",0,19))
# Out:
# P('he'|subj=John) 0.231880100934129
# P('she'|subj=John) 0.7681199029872292

# %%
print("P('she'|subj=Mary)",compute_average(asp_perfective_connective2,"she",19,38))
print("P('he'|subj=Mary)",compute_average(asp_perfective_connective2,"he",19,38))
# Out:
# P('she'|subj=Mary) 0.6783659583643863
# P('he'|subj=Mary) 0.3216340643794913

# %% [markdown]
# ## Stimuli with imperfective transfer of possession verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
asp_imperfective_noprompt = pd.read_csv("../results/v1.1/exp1A_aspect_imperfective.csv")
asp_imperfective_noprompt = asp_imperfective_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
asp_imperfective_noprompt
# Out:
#                                         Stimuli        He       She
# 0   John was bringing a glass of water to Mary.  0.870976  0.129024
# 1             John was carrying a tray to Mary.  0.866135  0.133865
# 2       John was delivering a subpoena to Mary.  0.870209  0.129791
# 3          John was flinging a frisbee to Mary.  0.865317  0.134683
# 4            John was giving a sweater to Mary.  0.866519  0.133481
# 5              John was handing a book to Mary.  0.859980  0.140020
# 6       John was kicking a soccer ball to Mary.  0.874301  0.125699
# 7          John was lobbing a football to Mary.  0.867503  0.132497
# 8            John was mailing a letter to Mary.  0.868540  0.131460
# 9          John was passing a sandwich to Mary.  0.866843  0.133157
# 10        John was rolling a toy truck to Mary.  0.870523  0.129477
# 11        John was sending a fruitcake to Mary.  0.854261  0.145739
# 12              John was serving chili to Mary.  0.860192  0.139808
# 13         John was shipping a package to Mary.  0.846802  0.153198
# 14             John was throwing a hat to Mary.  0.864156  0.135844
# 15       John was tossing a dish towel to Mary.  0.872832  0.127168
# 16     John was transmitting a message to Mary.  0.860988  0.139012
# 17               John was wiring money to Mary.  0.860562  0.139438
# 18  Mary was bringing a glass of water to John.  0.469700  0.530300
# 19            Mary was carrying a tray to John.  0.553972  0.446028
# 20      Mary was delivering a subpoena to John.  0.733410  0.266590
# 21         Mary was flinging a frisbee to John.  0.713340  0.286660
# 22           Mary was giving a sweater to John.  0.537452  0.462548
# 23             Mary was handing a book to John.  0.636785  0.363215
# 24      Mary was kicking a soccer ball to John.  0.662810  0.337190
# 25         Mary was lobbing a football to John.  0.777133  0.222867
# 26           Mary was mailing a letter to John.  0.667417  0.332583
# 27         Mary was passing a sandwich to John.  0.580503  0.419497
# 28        Mary was rolling a toy truck to John.  0.325414  0.674586
# 29        Mary was sending a fruitcake to John.  0.578400  0.421600
# 30              Mary was serving chili to John.  0.607512  0.392488
# 31         Mary was shipping a package to John.  0.430651  0.569349
# 32             Mary was throwing a hat to John.  0.640644  0.359356
# 33       Mary was tossing a dish towel to John.  0.579528  0.420472
# 34     Mary was transmitting a message to John.  0.683393  0.316607
# 35               Mary was wiring money to John.  0.690895  0.309105

# %%
print("P('He'|subj=John)", compute_average(asp_imperfective_noprompt,"He",0,19))
print("P('She'|subj=John)", compute_average(asp_imperfective_noprompt,"She",0,19))
# Out:
# P('He'|subj=John) 0.8440179056242892
# P('She'|subj=John) 0.15598210378697044

# %%
print("P('She'|subj=Mary)",compute_average(asp_imperfective_noprompt,"She",19,38))
print("P('He'|subj=Mary)",compute_average(asp_imperfective_noprompt,"He",19,38))
# Out:
# P('She'|subj=Mary) 0.38827887878698464
# P('He'|subj=Mary) 0.6117211142007042

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
asp_imperfective_connective1 = pd.read_csv("../results/v1.1/exp1A_aspect_imperfective_connective1.csv")
asp_imperfective_connective1 = asp_imperfective_connective1.sort_values(by='Stimuli').reset_index(drop=True)
asp_imperfective_connective1
# Out:
#                                               Stimuli        he       she
# 0   John was bringing a glass of water to Mary bec...  0.383829  0.616171
# 1            John was carrying a tray to Mary because  0.659191  0.340809
# 2      John was delivering a subpoena to Mary because  0.497989  0.502011
# 3         John was flinging a frisbee to Mary because  0.555491  0.444509
# 4           John was giving a sweater to Mary because  0.565994  0.434006
# 5             John was handing a book to Mary because  0.437851  0.562150
# 6      John was kicking a soccer ball to Mary because  0.479841  0.520159
# 7         John was lobbing a football to Mary because  0.363029  0.636971
# 8           John was mailing a letter to Mary because  0.855692  0.144308
# 9         John was passing a sandwich to Mary because  0.670256  0.329744
# 10       John was rolling a toy truck to Mary because  0.710786  0.289214
# 11       John was sending a fruitcake to Mary because  0.485156  0.514844
# 12             John was serving chili to Mary because  0.705679  0.294321
# 13        John was shipping a package to Mary because  0.585158  0.414842
# 14            John was throwing a hat to Mary because  0.562715  0.437285
# 15      John was tossing a dish towel to Mary because  0.484301  0.515699
# 16    John was transmitting a message to Mary because  0.739052  0.260948
# 17              John was wiring money to Mary because  0.634198  0.365802
# 18  Mary was bringing a glass of water to John bec...  0.081173  0.918827
# 19           Mary was carrying a tray to John because  0.040867  0.959133
# 20     Mary was delivering a subpoena to John because  0.062112  0.937888
# 21        Mary was flinging a frisbee to John because  0.161978  0.838022
# 22          Mary was giving a sweater to John because  0.104974  0.895026
# 23            Mary was handing a book to John because  0.105640  0.894360
# 24     Mary was kicking a soccer ball to John because  0.157232  0.842768
# 25        Mary was lobbing a football to John because  0.268465  0.731535
# 26          Mary was mailing a letter to John because  0.035530  0.964470
# 27        Mary was passing a sandwich to John because  0.107247  0.892753
# 28       Mary was rolling a toy truck to John because  0.057286  0.942714
# 29       Mary was sending a fruitcake to John because  0.076335  0.923665
# 30             Mary was serving chili to John because  0.019782  0.980218
# 31        Mary was shipping a package to John because  0.046749  0.953251
# 32            Mary was throwing a hat to John because  0.153550  0.846450
# 33      Mary was tossing a dish towel to John because  0.225661  0.774339
# 34    Mary was transmitting a message to John because  0.035839  0.964161
# 35              Mary was wiring money to John because  0.099086  0.900914

# %%
print("P('He'|subj=John)", compute_average(asp_imperfective_connective1,"he",0,19))
print("P('She'|subj=John)", compute_average(asp_imperfective_connective1,"she",0,19))
# Out:
# P('He'|subj=John) 0.5503886267542839
# P('She'|subj=John) 0.44961138304911163

# %%
print("P('She'|subj=Mary)",compute_average(asp_imperfective_connective1,"she",19,38))
print("P('He'|subj=Mary)",compute_average(asp_imperfective_connective1,"he",19,38))
# Out:
# P('She'|subj=Mary) 0.8965685542892007
# P('He'|subj=Mary) 0.10343145381878405

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
asp_imperfective_connective2 = pd.read_csv("../results/v1.1/exp1A_aspect_imperfective_connective2.csv")
asp_imperfective_connective2 = asp_imperfective_connective2.sort_values(by='Stimuli').reset_index(drop=True)
asp_imperfective_connective2
# Out:
#                                               Stimuli        he       she
# 0   John was bringing a glass of water to Mary and...  0.439997  0.560003
# 1   John was carrying a tray to Mary and, as a res...  0.767876  0.232124
# 2   John was delivering a subpoena to Mary and, as...  0.569301  0.430699
# 3   John was flinging a frisbee to Mary and, as a ...  0.661434  0.338566
# 4   John was giving a sweater to Mary and, as a re...  0.625763  0.374237
# 5   John was handing a book to Mary and, as a result,  0.503663  0.496337
# 6   John was kicking a soccer ball to Mary and, as...  0.877416  0.122584
# 7   John was lobbing a football to Mary and, as a ...  0.642230  0.357770
# 8   John was mailing a letter to Mary and, as a re...  0.517778  0.482222
# 9   John was passing a sandwich to Mary and, as a ...  0.463780  0.536220
# 10  John was rolling a toy truck to Mary and, as a...  0.802865  0.197135
# 11  John was sending a fruitcake to Mary and, as a...  0.258693  0.741307
# 12   John was serving chili to Mary and, as a result,  0.845154  0.154846
# 13  John was shipping a package to Mary and, as a ...  0.738055  0.261945
# 14  John was throwing a hat to Mary and, as a result,  0.721157  0.278843
# 15  John was tossing a dish towel to Mary and, as ...  0.657013  0.342987
# 16  John was transmitting a message to Mary and, a...  0.269811  0.730189
# 17    John was wiring money to Mary and, as a result,  0.484507  0.515493
# 18  Mary was bringing a glass of water to John and...  0.193348  0.806652
# 19  Mary was carrying a tray to John and, as a res...  0.123185  0.876815
# 20  Mary was delivering a subpoena to John and, as...  0.151582  0.848418
# 21  Mary was flinging a frisbee to John and, as a ...  0.222250  0.777750
# 22  Mary was giving a sweater to John and, as a re...  0.251547  0.748453
# 23  Mary was handing a book to John and, as a result,  0.235388  0.764612
# 24  Mary was kicking a soccer ball to John and, as...  0.174448  0.825552
# 25  Mary was lobbing a football to John and, as a ...  0.233740  0.766260
# 26  Mary was mailing a letter to John and, as a re...  0.197457  0.802543
# 27  Mary was passing a sandwich to John and, as a ...  0.146161  0.853839
# 28  Mary was rolling a toy truck to John and, as a...  0.189312  0.810688
# 29  Mary was sending a fruitcake to John and, as a...  0.197930  0.802070
# 30   Mary was serving chili to John and, as a result,  0.125960  0.874040
# 31  Mary was shipping a package to John and, as a ...  0.152211  0.847789
# 32  Mary was throwing a hat to John and, as a result,  0.238558  0.761442
# 33  Mary was tossing a dish towel to John and, as ...  0.266770  0.733230
# 34  Mary was transmitting a message to John and, a...  0.174065  0.825935
# 35    Mary was wiring money to John and, as a result,  0.204121  0.795879

# %%
print("P('He'|subj=John)", compute_average(asp_imperfective_connective2,"he",0,19))
print("P('She'|subj=John)", compute_average(asp_imperfective_connective2,"she",0,19))
# Out:
# P('He'|subj=John) 0.5810443719750956
# P('She'|subj=John) 0.4189556401811148

# %%
print("P('She'|subj=Mary)",compute_average(asp_imperfective_connective2,"she",19,38))
print("P('He'|subj=Mary)",compute_average(asp_imperfective_connective2,"he",19,38))
# Out:
# P('She'|subj=Mary) 0.8067831221748801
# P('He'|subj=Mary) 0.19321687168934765
