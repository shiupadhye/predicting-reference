# %%
import pandas as pd
import numpy as np

# %%
#-------------- Helper Functions ------------- #
def compute_average(df, col,start_idx, end_idx):
    return np.mean(df[col].values[start_idx:end_idx])

# %% [markdown]
# ## Stimuli with implicit causality verbs (subject-biased)

# %% [markdown]
# #### Stimuli with no prompt

# %%
IC1_noprompt = pd.read_csv("../results/v1.2/exp1A_IC1.csv")
IC1_noprompt = IC1_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
IC1_noprompt
# Out:
#                      Stimuli        He       She
# 0      John aggravated Mary.  0.721084  0.278917
# 1          John amazed Mary.  0.601427  0.398573
# 2          John amused Mary.  0.777413  0.222587
# 3         John annoyed Mary.  0.775718  0.224282
# 4   John apologized to Mary.  0.775338  0.224662
# 5           John bored Mary.  0.755822  0.244178
# 6         John charmed Mary.  0.765251  0.234749
# 7    John confessed to Mary.  0.761504  0.238496
# 8        John deceived Mary.  0.767077  0.232923
# 9    John disappointed Mary.  0.833739  0.166261
# 10    John exasperated Mary.  0.769632  0.230368
# 11     John fascinated Mary.  0.766466  0.233534
# 12     John frightened Mary.  0.612758  0.387242
# 13     John humiliated Mary.  0.774249  0.225751
# 14     John infuriated Mary.  0.771058  0.228942
# 15       John inspires Mary.  0.769548  0.230452
# 16    John intimidates Mary.  0.769167  0.230833
# 17       John offended Mary.  0.775014  0.224986
# 18         John scares Mary.  0.761880  0.238120
# 19      John surprised Mary.  0.790041  0.209959
# 20     Mary aggravated John.  0.500352  0.499648
# 21         Mary amazed John.  0.506257  0.493743
# 22         Mary amused John.  0.370570  0.629430
# 23        Mary annoyed John.  0.373387  0.626613
# 24  Mary apologized to John.  0.701111  0.298889
# 25          Mary bored John.  0.493810  0.506190
# 26        Mary charmed John.  0.490348  0.509652
# 27   Mary confessed to John.  0.240592  0.759408
# 28       Mary deceived John.  0.361049  0.638951
# 29   Mary disappointed John.  0.509104  0.490896
# 30    Mary exasperated John.  0.461157  0.538843
# 31     Mary fascinated John.  0.387802  0.612198
# 32     Mary frightened John.  0.399436  0.600564
# 33     Mary humiliated John.  0.394826  0.605174
# 34     Mary infuriated John.  0.400213  0.599787
# 35       Mary inspires John.  0.476398  0.523602
# 36    Mary intimidates John.  0.360561  0.639440
# 37       Mary offended John.  0.403672  0.596328
# 38         Mary scares John.  0.332952  0.667048
# 39      Mary surprised John.  0.431946  0.568054

# %%
print("P('He'|subj=John)", compute_average(IC1_noprompt,"He",0,20))
print("P('She'|subj=John)", compute_average(IC1_noprompt,"She",0,20))
# Out:
# P('He'|subj=John) 0.7547092646360397
# P('She'|subj=John) 0.24529073461890222

# %%
print("P('She'|subj=Mary)",compute_average(IC1_noprompt,"She",20,40))
print("P('He'|subj=Mary)",compute_average(IC1_noprompt,"He",20,40))
# Out:
# P('She'|subj=Mary) 0.5702228903770447
# P('He'|subj=Mary) 0.4297771193087101

# %% [markdown]
# #### Prompt with connective: "because"

# %%
IC1_connective1 = pd.read_csv("../results/v1.2/exp1A_IC1_connective1.csv")
IC1_connective1 = IC1_connective1.sort_values(by='Stimuli').reset_index(drop=True)
IC1_connective1
# Out:
#                             Stimuli        he       she
# 0      John aggravated Mary because  0.655272  0.344728
# 1          John amazed Mary because  0.891511  0.108489
# 2          John amused Mary because  0.692549  0.307451
# 3         John annoyed Mary because  0.614194  0.385806
# 4   John apologized to Mary because  0.555888  0.444112
# 5           John bored Mary because  0.384189  0.615811
# 6         John charmed Mary because  0.629117  0.370883
# 7    John confessed to Mary because  0.874479  0.125521
# 8        John deceived Mary because  0.501234  0.498766
# 9    John disappointed Mary because  0.728690  0.271310
# 10    John exasperated Mary because  0.627773  0.372227
# 11     John fascinated Mary because  0.682570  0.317430
# 12     John frightened Mary because  0.621747  0.378253
# 13     John humiliated Mary because  0.441715  0.558285
# 14     John infuriated Mary because  0.590790  0.409210
# 15       John inspires Mary because  0.653209  0.346791
# 16    John intimidates Mary because  0.641409  0.358591
# 17       John offended Mary because  0.686358  0.313642
# 18         John scares Mary because  0.714973  0.285027
# 19      John surprised Mary because  0.822492  0.177508
# 20     Mary aggravated John because  0.434679  0.565321
# 21         Mary amazed John because  0.312264  0.687737
# 22         Mary amused John because  0.505397  0.494603
# 23        Mary annoyed John because  0.650144  0.349856
# 24  Mary apologized to John because  0.581358  0.418642
# 25          Mary bored John because  0.803650  0.196350
# 26        Mary charmed John because  0.412480  0.587520
# 27   Mary confessed to John because  0.027766  0.972234
# 28       Mary deceived John because  0.307561  0.692439
# 29   Mary disappointed John because  0.503266  0.496734
# 30    Mary exasperated John because  0.741985  0.258015
# 31     Mary fascinated John because  0.596336  0.403664
# 32     Mary frightened John because  0.719208  0.280792
# 33     Mary humiliated John because  0.776971  0.223029
# 34     Mary infuriated John because  0.716147  0.283853
# 35       Mary inspires John because  0.353563  0.646437
# 36    Mary intimidates John because  0.463249  0.536751
# 37       Mary offended John because  0.742799  0.257201
# 38         Mary scares John because  0.601321  0.398679
# 39      Mary surprised John because  0.426424  0.573576

# %%
print("P('he'|subj=John)=", compute_average(IC1_connective1,"he",0,20))
print("P('she'|subj=John)=", compute_average(IC1_connective1,"she",0,20))
# Out:
# P('he'|subj=John)= 0.6505079418420792
# P('she'|subj=John)= 0.34949205368757247

# %%
print("P('she'|subj=Mary)=",compute_average(IC1_connective1,"she",20,40))
print("P('he'|subj=Mary)=",compute_average(IC1_connective1,"he",20,40))
# Out:
# P('she'|subj=Mary)= 0.46617165207862854
# P('he'|subj=Mary)= 0.5338283604942262

# %% [markdown]
# #### Prompt with connective phrase: "and, as a result,"

# %%
IC1_connective2 = pd.read_csv("../results/v1.2/exp1A_IC1_connective2.csv")
IC1_connective2 = IC1_connective2.sort_values(by='Stimuli').reset_index(drop=True)
IC1_connective2
# Out:
#                                       Stimuli        he       she
# 0      John aggravated Mary and, as a result,  0.225138  0.774862
# 1          John amazed Mary and, as a result,  0.074871  0.925129
# 2          John amused Mary and, as a result,  0.205753  0.794247
# 3         John annoyed Mary and, as a result,  0.163479  0.836521
# 4   John apologized to Mary and, as a result,  0.258110  0.741890
# 5           John bored Mary and, as a result,  0.155870  0.844130
# 6         John charmed Mary and, as a result,  0.208752  0.791248
# 7    John confessed to Mary and, as a result,  0.145950  0.854050
# 8        John deceived Mary and, as a result,  0.151750  0.848250
# 9    John disappointed Mary and, as a result,  0.350159  0.649841
# 10    John exasperated Mary and, as a result,  0.106930  0.893070
# 11     John fascinated Mary and, as a result,  0.223960  0.776040
# 12     John frightened Mary and, as a result,  0.147810  0.852190
# 13     John humiliated Mary and, as a result,  0.228521  0.771479
# 14     John infuriated Mary and, as a result,  0.156576  0.843424
# 15       John inspires Mary and, as a result,  0.037033  0.962967
# 16    John intimidates Mary and, as a result,  0.062861  0.937139
# 17       John offended Mary and, as a result,  0.200200  0.799800
# 18         John scares Mary and, as a result,  0.073497  0.926503
# 19      John surprised Mary and, as a result,  0.170137  0.829863
# 20     Mary aggravated John and, as a result,  0.806738  0.193262
# 21         Mary amazed John and, as a result,  0.900148  0.099852
# 22         Mary amused John and, as a result,  0.853946  0.146054
# 23        Mary annoyed John and, as a result,  0.823973  0.176027
# 24  Mary apologized to John and, as a result,  0.874113  0.125887
# 25          Mary bored John and, as a result,  0.874040  0.125960
# 26        Mary charmed John and, as a result,  0.759788  0.240212
# 27   Mary confessed to John and, as a result,  0.551593  0.448407
# 28       Mary deceived John and, as a result,  0.758391  0.241609
# 29   Mary disappointed John and, as a result,  0.861513  0.138487
# 30    Mary exasperated John and, as a result,  0.866883  0.133117
# 31     Mary fascinated John and, as a result,  0.884865  0.115135
# 32     Mary frightened John and, as a result,  0.905408  0.094592
# 33     Mary humiliated John and, as a result,  0.813853  0.186147
# 34     Mary infuriated John and, as a result,  0.804448  0.195552
# 35       Mary inspires John and, as a result,  0.967758  0.032242
# 36    Mary intimidates John and, as a result,  0.907418  0.092582
# 37       Mary offended John and, as a result,  0.830597  0.169403
# 38         Mary scares John and, as a result,  0.933514  0.066486
# 39      Mary surprised John and, as a result,  0.849255  0.150745

# %%
print("P('he'|subj=John)=", compute_average(IC1_connective2,"he",0,20))
print("P('she'|subj=John)=", compute_average(IC1_connective2,"she",0,20))
# Out:
# P('he'|subj=John)= 0.16736780405044555
# P('she'|subj=John)= 0.8326321870088578

# %%
print("P('she'|subj=Mary)=",compute_average(IC1_connective2,"she",20,40))
print("P('he'|subj=Mary)=",compute_average(IC1_connective2,"he",20,40))
# Out:
# P('she'|subj=Mary)= 0.15858782287687062
# P('he'|subj=Mary)= 0.8414121806621552

# %% [markdown]
# ## Stimuli with implicit causality verbs (Object-Biased)

# %% [markdown]
# #### Stimuli with no prompt

# %%
IC2_noprompt = pd.read_csv("../results/v1.2/exp1A_IC2.csv")
IC2_noprompt = IC2_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
IC2_noprompt
# Out:
#                      Stimuli        He       She
# 0        John assisted Mary.  0.610845  0.389155
# 1          John blames Mary.  0.717290  0.282710
# 2       John comforted Mary.  0.768766  0.231234
# 3   John congratulated Mary.  0.770229  0.229771
# 4       John corrected Mary.  0.758832  0.241168
# 5         John detests Mary.  0.777841  0.222159
# 6          John envies Mary.  0.776508  0.223492
# 7           John fears Mary.  0.658306  0.341694
# 8           John hates Mary.  0.778979  0.221021
# 9          John helped Mary.  0.260959  0.739041
# 10         John mocked Mary.  0.768736  0.231264
# 11        John noticed Mary.  0.658365  0.341635
# 12       John pacified Mary.  0.763962  0.236038
# 13        John praised Mary.  0.665589  0.334411
# 14     John reproached Mary.  0.770524  0.229476
# 15        John scolded Mary.  0.769295  0.230705
# 16      John stared at Mary.  0.776852  0.223148
# 17        John thanked Mary.  0.776367  0.223633
# 18         John trusts Mary.  0.783694  0.216306
# 19         John values Mary.  0.789569  0.210431
# 20       Mary assisted John.  0.458059  0.541941
# 21         Mary blames John.  0.364931  0.635069
# 22      Mary comforted John.  0.221647  0.778353
# 23  Mary congratulated John.  0.386257  0.613743
# 24      Mary corrected John.  0.356842  0.643158
# 25        Mary detests John.  0.723959  0.276041
# 26         Mary envies John.  0.717333  0.282667
# 27          Mary fears John.  0.327711  0.672289
# 28          Mary hates John.  0.725479  0.274521
# 29         Mary helped John.  0.634894  0.365106
# 30         Mary mocked John.  0.408689  0.591311
# 31        Mary noticed John.  0.581984  0.418016
# 32       Mary pacified John.  0.333128  0.666872
# 33        Mary praised John.  0.597542  0.402458
# 34     Mary reproached John.  0.564276  0.435724
# 35        Mary scolded John.  0.552197  0.447803
# 36      Mary stared at John.  0.715371  0.284629
# 37        Mary thanked John.  0.579012  0.420988
# 38         Mary trusts John.  0.717051  0.282949
# 39         Mary values John.  0.369906  0.630094

# %%
print("P('He'|subj=John)", compute_average(IC2_noprompt,"He",0,20))
print("P('She'|subj=John)", compute_average(IC2_noprompt,"She",0,20))
# Out:
# P('He'|subj=John) 0.7200753480195999
# P('She'|subj=John) 0.2799246534705162

# %%
print("P('She'|subj=Mary)",compute_average(IC2_noprompt,"She",20,40))
print("P('He'|subj=Mary)",compute_average(IC2_noprompt,"He",20,40))
# Out:
# P('She'|subj=Mary) 0.48318650424480436
# P('He'|subj=Mary) 0.5168134890496731

# %% [markdown]
# #### Stimulus with connective: "because"

# %%
IC2_connective1 = pd.read_csv("../results/v1.2/exp1A_IC2_connective1.csv")
IC2_connective1 = IC2_connective1.sort_values(by='Stimuli').reset_index(drop=True)
IC2_connective1
# Out:
#                             Stimuli        he       she
# 0        John assisted Mary because  0.354593  0.645407
# 1          John blames Mary because  0.314032  0.685968
# 2       John comforted Mary because  0.404134  0.595866
# 3   John congratulated Mary because  0.437088  0.562912
# 4       John corrected Mary because  0.397097  0.602903
# 5         John detests Mary because  0.472704  0.527296
# 6          John envies Mary because  0.482340  0.517660
# 7           John fears Mary because  0.525413  0.474587
# 8           John hates Mary because  0.442481  0.557519
# 9          John helped Mary because  0.387510  0.612490
# 10         John mocked Mary because  0.475317  0.524683
# 11        John noticed Mary because  0.448177  0.551823
# 12       John pacified Mary because  0.477811  0.522189
# 13        John praised Mary because  0.487094  0.512906
# 14     John reproached Mary because  0.305999  0.694001
# 15        John scolded Mary because  0.325236  0.674764
# 16      John stared at Mary because  0.411617  0.588383
# 17        John thanked Mary because  0.389590  0.610410
# 18         John trusts Mary because  0.459174  0.540826
# 19         John values Mary because  0.500345  0.499655
# 20       Mary assisted John because  0.425970  0.574030
# 21         Mary blames John because  0.825521  0.174479
# 22      Mary comforted John because  0.841403  0.158597
# 23  Mary congratulated John because  0.773794  0.226206
# 24      Mary corrected John because  0.494028  0.505972
# 25        Mary detests John because  0.830893  0.169107
# 26         Mary envies John because  0.878274  0.121726
# 27          Mary fears John because  0.848158  0.151842
# 28          Mary hates John because  0.890491  0.109509
# 29         Mary helped John because  0.359846  0.640154
# 30         Mary mocked John because  0.803022  0.196978
# 31        Mary noticed John because  0.860219  0.139781
# 32       Mary pacified John because  0.464189  0.535811
# 33        Mary praised John because  0.919184  0.080816
# 34     Mary reproached John because  0.912553  0.087447
# 35        Mary scolded John because  0.905145  0.094855
# 36      Mary stared at John because  0.805345  0.194655
# 37        Mary thanked John because  0.718523  0.281477
# 38         Mary trusts John because  0.695328  0.304672
# 39         Mary values John because  0.791678  0.208322

# %%
print("P('he'|subj=John)", compute_average(IC2_connective1,"he",0,20))
print("P('she'|subj=John)", compute_average(IC2_connective1,"she",0,20))
# Out:
# P('he'|subj=John) 0.4248876392841339
# P('she'|subj=John) 0.5751123532652855

# %%
print("P('she'|subj=Mary)",compute_average(IC2_connective1,"she",20,40))
print("P('he'|subj=Mary)",compute_average(IC2_connective1,"he",20,40))
# Out:
# P('she'|subj=Mary) 0.2478217788040638
# P('he'|subj=Mary) 0.7521782264113426

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
IC2_connective2 = pd.read_csv("../results/v1.2/exp1A_IC2_connective2.csv")
IC2_connective2 = IC2_connective2.sort_values(by='Stimuli').reset_index(drop=True)
IC2_connective2
# Out:
#                                       Stimuli        he       she
# 0        John assisted Mary and, as a result,  0.257098  0.742902
# 1          John blames Mary and, as a result,  0.311815  0.688185
# 2       John comforted Mary and, as a result,  0.149767  0.850233
# 3   John congratulated Mary and, as a result,  0.141686  0.858314
# 4       John corrected Mary and, as a result,  0.349950  0.650050
# 5         John detests Mary and, as a result,  0.721989  0.278011
# 6          John envies Mary and, as a result,  0.564861  0.435139
# 7           John fears Mary and, as a result,  0.770871  0.229129
# 8           John hates Mary and, as a result,  0.629299  0.370701
# 9          John helped Mary and, as a result,  0.229891  0.770109
# 10         John mocked Mary and, as a result,  0.349685  0.650315
# 11        John noticed Mary and, as a result,  0.676284  0.323716
# 12       John pacified Mary and, as a result,  0.175698  0.824302
# 13        John praised Mary and, as a result,  0.294918  0.705082
# 14     John reproached Mary and, as a result,  0.138908  0.861092
# 15        John scolded Mary and, as a result,  0.203624  0.796376
# 16      John stared at Mary and, as a result,  0.324427  0.675573
# 17        John thanked Mary and, as a result,  0.206271  0.793729
# 18         John trusts Mary and, as a result,  0.273415  0.726585
# 19         John values Mary and, as a result,  0.678135  0.321865
# 20       Mary assisted John and, as a result,  0.565416  0.434584
# 21         Mary blames John and, as a result,  0.712393  0.287607
# 22      Mary comforted John and, as a result,  0.829831  0.170169
# 23  Mary congratulated John and, as a result,  0.908976  0.091024
# 24      Mary corrected John and, as a result,  0.576484  0.423516
# 25        Mary detests John and, as a result,  0.369741  0.630259
# 26         Mary envies John and, as a result,  0.551533  0.448467
# 27          Mary fears John and, as a result,  0.325622  0.674378
# 28          Mary hates John and, as a result,  0.469587  0.530413
# 29         Mary helped John and, as a result,  0.707774  0.292226
# 30         Mary mocked John and, as a result,  0.775773  0.224227
# 31        Mary noticed John and, as a result,  0.427986  0.572014
# 32       Mary pacified John and, as a result,  0.856996  0.143004
# 33        Mary praised John and, as a result,  0.955754  0.044246
# 34     Mary reproached John and, as a result,  0.944660  0.055340
# 35        Mary scolded John and, as a result,  0.898107  0.101893
# 36      Mary stared at John and, as a result,  0.817921  0.182079
# 37        Mary thanked John and, as a result,  0.941363  0.058637
# 38         Mary trusts John and, as a result,  0.810011  0.189989
# 39         Mary values John and, as a result,  0.491077  0.508923

# %%
print("P('He'|subj=John)", compute_average(IC2_connective2,"he",0,20))
print("P('She'|subj=John)", compute_average(IC2_connective2,"she",0,20))
# Out:
# P('He'|subj=John) 0.3724295660853386
# P('She'|subj=John) 0.627570416778326

# %%
print("P('He'|subj=Mary)",compute_average(IC2_connective2,"he",20,40))
print("P('She'|subj=Mary)",compute_average(IC2_connective2,"she",20,40))
# Out:
# P('He'|subj=Mary) 0.6968502074480056
# P('She'|subj=Mary) 0.3031497934833169

# %% [markdown]
# ## Stimuli with motion verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
motion_noprompt = pd.read_csv("../results/v1.2/exp1A_motion.csv")
motion_noprompt = motion_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
motion_noprompt
# Out:
#                  Stimuli        He       She
# 0    John drove to Mary.  0.762922  0.237078
# 1     John flew to Mary.  0.762187  0.237813
# 2   John jogged to Mary.  0.764899  0.235101
# 3      John ran to Mary.  0.775902  0.224098
# 4     John swam to Mary.  0.765743  0.234257
# 5   John walked to Mary.  0.768063  0.231937
# 6    Mary drove to John.  0.210720  0.789280
# 7     Mary flew to John.  0.289899  0.710101
# 8   Mary jogged to John.  0.079740  0.920260
# 9      Mary ran to John.  0.258260  0.741740
# 10    Mary swam to John.  0.169844  0.830156
# 11  Mary walked to John.  0.146943  0.853056

# %%
print("P('He'|subj=John)", compute_average(motion_noprompt,"He",0,6))
print("P('She'|subj=John)", compute_average(motion_noprompt,"She",0,6))
# Out:
# P('He'|subj=John) 0.7666192948818207
# P('She'|subj=John) 0.23338069270054498

# %%
print("P('He'|subj=Mary)",compute_average(motion_noprompt,"He",6,12))
print("P('She'|subj=Mary)",compute_average(motion_noprompt,"She",6,12))
# Out:
# P('He'|subj=Mary) 0.19256780917445818
# P('She'|subj=Mary) 0.8074321846167246

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
motion_connective1 = pd.read_csv("../results/v1.2/exp1A_motion_connective1.csv")
motion_connective1 = motion_connective1.sort_values(by='Stimuli').reset_index(drop=True)
motion_connective1
# Out:
#                         Stimuli        he       she
# 0    John drove to Mary because  0.447173  0.552827
# 1     John flew to Mary because  0.417158  0.582842
# 2   John jogged to Mary because  0.424128  0.575872
# 3      John ran to Mary because  0.522264  0.477736
# 4     John swam to Mary because  0.590335  0.409665
# 5   John walked to Mary because  0.523708  0.476292
# 6    Mary drove to John because  0.142561  0.857439
# 7     Mary flew to John because  0.089907  0.910093
# 8   Mary jogged to John because  0.159771  0.840229
# 9      Mary ran to John because  0.258946  0.741054
# 10    Mary swam to John because  0.099270  0.900730
# 11  Mary walked to John because  0.106018  0.893982

# %%
print("P('he'|subj=John)", compute_average(motion_connective1,"he",0,6))
print("P('she'|subj=John)", compute_average(motion_connective1,"she",0,6))
# Out:
# P('he'|subj=John) 0.48746101558208466
# P('she'|subj=John) 0.5125389794508616

# %%
print("P('she'|subj=Mary)",compute_average(motion_connective1,"she",6,12))
print("P('he'|subj=Mary)",compute_average(motion_connective1,"he",6,12))
# Out:
# P('she'|subj=Mary) 0.8572545647621155
# P('he'|subj=Mary) 0.14274545138080916

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
motion_connective2 = pd.read_csv("../results/v1.2/exp1A_motion_connective2.csv")
motion_connective2 = motion_connective2.sort_values(by='Stimuli').reset_index(drop=True)
motion_connective2
# Out:
#                                   Stimuli        he       she
# 0    John drove to Mary and, as a result,  0.257730  0.742270
# 1     John flew to Mary and, as a result,  0.355770  0.644230
# 2   John jogged to Mary and, as a result,  0.382166  0.617834
# 3      John ran to Mary and, as a result,  0.158376  0.841624
# 4     John swam to Mary and, as a result,  0.312586  0.687414
# 5   John walked to Mary and, as a result,  0.285744  0.714256
# 6    Mary drove to John and, as a result,  0.447589  0.552411
# 7     Mary flew to John and, as a result,  0.359436  0.640564
# 8   Mary jogged to John and, as a result,  0.441832  0.558168
# 9      Mary ran to John and, as a result,  0.762597  0.237403
# 10    Mary swam to John and, as a result,  0.374330  0.625670
# 11  Mary walked to John and, as a result,  0.426315  0.573685

# %%
print("P('he'|subj=John)", compute_average(motion_connective2,"he",0,6))
print("P('she'|subj=John)", compute_average(motion_connective2,"she",0,6))
# Out:
# P('he'|subj=John) 0.29206209381421405
# P('she'|subj=John) 0.7079378962516785

# %%
print("P('she'|subj=Mary)",compute_average(motion_connective2,"she",6,12))
print("P('he'|subj=Mary)",compute_average(motion_connective2,"he",6,12))
# Out:
# P('she'|subj=Mary) 0.5313166057070097
# P('he'|subj=Mary) 0.4686834067106247

# %% [markdown]
# ## Stimuli with transfer of possession verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
transofposs_noprompt = pd.read_csv("../results/v1.2/exp1A_transofposs.csv")
transofposs_noprompt = transofposs_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
transofposs_noprompt
# Out:
#                                Stimuli        He       She
# 0        John brought flowers to Mary.  0.772832  0.227168
# 1       John carried a banana to Mary.  0.775205  0.224795
# 2            John gave a book to Mary.  0.775486  0.224514
# 3          John handed a gift to Mary.  0.778342  0.221658
# 4   John kicked a soccer ball to Mary.  0.780941  0.219059
# 5        John mailed a letter to Mary.  0.775935  0.224065
# 6    John rolled a beach ball to Mary.  0.786420  0.213580
# 7        John threw a Frisbee to Mary.  0.781741  0.218259
# 8        Mary brought flowers to John.  0.726218  0.273782
# 9       Mary carried a banana to John.  0.731801  0.268199
# 10           Mary gave a book to John.  0.411571  0.588429
# 11         Mary handed a gift to John.  0.286393  0.713607
# 12  Mary kicked a soccer ball to John.  0.741161  0.258839
# 13       Mary mailed a letter to John.  0.246825  0.753175
# 14   Mary rolled a beach ball to John.  0.744268  0.255732
# 15       Mary threw a Frisbee to John.  0.734157  0.265843

# %%
print("P('He'|subj=John)", compute_average(transofposs_noprompt,"He",0,8))
print("P('She'|subj=John)", compute_average(transofposs_noprompt,"She",0,8))
# Out:
# P('He'|subj=John) 0.778362825512886
# P('She'|subj=John) 0.2216371800750494

# %%
print("P('She'|subj=Mary)",compute_average(transofposs_noprompt,"She",8,16))
print("P('He'|subj=Mary)",compute_average(transofposs_noprompt,"He",8,16))
# Out:
# P('She'|subj=Mary) 0.42220087721943855
# P('He'|subj=Mary) 0.577799154445529

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
transofposs_connective1 = pd.read_csv("../results/v1.2/exp1A_transofposs_connective1.csv")
transofposs_connective1 = transofposs_connective1.sort_values(by='Stimuli').reset_index(drop=True)
transofposs_connective1
# Out:
#                                       Stimuli        he       she
# 0        John brought flowers to Mary because  0.497299  0.502701
# 1       John carried a banana to Mary because  0.593269  0.406731
# 2            John gave a book to Mary because  0.482532  0.517468
# 3          John handed a gift to Mary because  0.538364  0.461636
# 4   John kicked a soccer ball to Mary because  0.320234  0.679766
# 5        John mailed a letter to Mary because  0.633773  0.366227
# 6    John rolled a beach ball to Mary because  0.514960  0.485040
# 7        John threw a Frisbee to Mary because  0.508285  0.491715
# 8        Mary brought flowers to John because  0.390493  0.609507
# 9       Mary carried a banana to John because  0.152586  0.847414
# 10           Mary gave a book to John because  0.298831  0.701169
# 11         Mary handed a gift to John because  0.324067  0.675933
# 12  Mary kicked a soccer ball to John because  0.634273  0.365727
# 13       Mary mailed a letter to John because  0.230193  0.769807
# 14   Mary rolled a beach ball to John because  0.264116  0.735884
# 15       Mary threw a Frisbee to John because  0.539591  0.460409

# %%
print("P('he'|subj=John)", compute_average(transofposs_connective1,"he",0,8))
print("P('she'|subj=John)", compute_average(transofposs_connective1,"she",0,8))
# Out:
# P('he'|subj=John) 0.5110896751284599
# P('she'|subj=John) 0.4889103136956692

# %%
print("P('she'|subj=Mary)",compute_average(transofposs_connective1,"she",8,16))
print("P('he'|subj=Mary)",compute_average(transofposs_connective1,"he",8,16))
# Out:
# P('she'|subj=Mary) 0.6457312889397144
# P('he'|subj=Mary) 0.3542687129229307

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
transofposs_connective2 = pd.read_csv("../results/v1.2/exp1A_transofposs_connective2.csv")
transofposs_connective2 = transofposs_connective2.sort_values(by='Stimuli').reset_index(drop=True)
transofposs_connective2
# Out:
#                                               Stimuli        he       she
# 0      John brought flowers to Mary and, as a result,  0.283979  0.716021
# 1     John carried a banana to Mary and, as a result,  0.471196  0.528804
# 2          John gave a book to Mary and, as a result,  0.199811  0.800189
# 3        John handed a gift to Mary and, as a result,  0.121083  0.878917
# 4   John kicked a soccer ball to Mary and, as a re...  0.385462  0.614538
# 5      John mailed a letter to Mary and, as a result,  0.180134  0.819866
# 6   John rolled a beach ball to Mary and, as a res...  0.444939  0.555061
# 7      John threw a Frisbee to Mary and, as a result,  0.271007  0.728993
# 8      Mary brought flowers to John and, as a result,  0.789048  0.210952
# 9     Mary carried a banana to John and, as a result,  0.392915  0.607085
# 10         Mary gave a book to John and, as a result,  0.853121  0.146879
# 11       Mary handed a gift to John and, as a result,  0.643546  0.356454
# 12  Mary kicked a soccer ball to John and, as a re...  0.782596  0.217404
# 13     Mary mailed a letter to John and, as a result,  0.756722  0.243278
# 14  Mary rolled a beach ball to John and, as a res...  0.759918  0.240082
# 15     Mary threw a Frisbee to John and, as a result,  0.750482  0.249518

# %%
print("P('he'|subj=John)", compute_average(transofposs_connective2,"he",0,8))
print("P('she'|subj=John)", compute_average(transofposs_connective2,"she",0,8))
# Out:
# P('he'|subj=John) 0.2947014272212982
# P('she'|subj=John) 0.7052985653281212

# %%
print("P('she'|subj=Mary)",compute_average(transofposs_connective2,"she",8,16))
print("P('he'|subj=Mary)",compute_average(transofposs_connective2,"he",8,16))
# Out:
# P('she'|subj=Mary) 0.2839562576264143
# P('he'|subj=Mary) 0.7160437293350697

# %% [markdown]
# ## Stimuli with perfective transfer of possession verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
asp_perfective_noprompt = pd.read_csv("../results/v1.2/exp1A_aspect_perfective.csv")
asp_perfective_noprompt = asp_perfective_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
asp_perfective_noprompt
# Out:
#                                     Stimuli        He       She
# 0    John brought a glass of water to Mary.  0.794128  0.205872
# 1              John carried a tray to Mary.  0.772356  0.227644
# 2        John delivered a subpoena to Mary.  0.777829  0.222171
# 3             John flung a frisbee to Mary.  0.779130  0.220870
# 4   John forwarded a gossipy email to Mary.  0.778045  0.221955
# 5              John gave a sweater to Mary.  0.781671  0.218329
# 6               John handed a book to Mary.  0.771957  0.228043
# 7        John kicked a soccer ball to Mary.  0.780941  0.219059
# 8           John lobbed a football to Mary.  0.776527  0.223473
# 9             John mailed a letter to Mary.  0.775935  0.224065
# 10          John passed a sandwich to Mary.  0.798835  0.201166
# 11         John rolled a toy truck to Mary.  0.782542  0.217458
# 12           John sent a fruitcake to Mary.  0.766026  0.233974
# 13               John served chili to Mary.  0.773801  0.226199
# 14          John shipped a package to Mary.  0.762974  0.237026
# 15                John threw a hat to Mary.  0.778441  0.221559
# 16        John tossed a dish towel to Mary.  0.784459  0.215541
# 17      John transmitted a message to Mary.  0.768802  0.231198
# 18                John wired money to Mary.  0.781178  0.218822
# 19   Mary brought a glass of water to John.  0.728748  0.271252
# 20             Mary carried a tray to John.  0.733815  0.266185
# 21       Mary delivered a subpoena to John.  0.206103  0.793897
# 22            Mary flung a frisbee to John.  0.738339  0.261661
# 23  Mary forwarded a gossipy email to John.  0.305802  0.694198
# 24             Mary gave a sweater to John.  0.345631  0.654369
# 25              Mary handed a book to John.  0.539976  0.460024
# 26       Mary kicked a soccer ball to John.  0.741161  0.258839
# 27          Mary lobbed a football to John.  0.737463  0.262537
# 28            Mary mailed a letter to John.  0.246825  0.753175
# 29          Mary passed a sandwich to John.  0.725468  0.274533
# 30         Mary rolled a toy truck to John.  0.741140  0.258860
# 31           Mary sent a fruitcake to John.  0.715477  0.284523
# 32               Mary served chili to John.  0.326812  0.673188
# 33          Mary shipped a package to John.  0.064997  0.935003
# 34                Mary threw a hat to John.  0.733175  0.266825
# 35        Mary tossed a dish towel to John.  0.743744  0.256256
# 36      Mary transmitted a message to John.  0.392314  0.607686
# 37                Mary wired money to John.  0.551523  0.448477

# %%
print("P('He'|subj=John)", compute_average(asp_perfective_noprompt,"He",0,19))
print("P('She'|subj=John)", compute_average(asp_perfective_noprompt,"She",0,19))
# Out:
# P('He'|subj=John) 0.7781882693893031
# P('She'|subj=John) 0.22181174159049988

# %%
print("P('She'|subj=Mary)",compute_average(asp_perfective_noprompt,"She",19,38))
print("P('He'|subj=Mary)",compute_average(asp_perfective_noprompt,"He",19,38))
# Out:
# P('She'|subj=Mary) 0.4569204606507954
# P('He'|subj=Mary) 0.5430795389570688

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
asp_perfective_connective1 = pd.read_csv("../results/v1.2/exp1A_aspect_perfective_connective1.csv")
asp_perfective_connective1 = asp_perfective_connective1.sort_values(by='Stimuli').reset_index(drop=True)
asp_perfective_connective1
# Out:
#                                            Stimuli        he       she
# 0    John brought a glass of water to Mary because  0.518929  0.481071
# 1              John carried a tray to Mary because  0.582575  0.417425
# 2        John delivered a subpoena to Mary because  0.452164  0.547836
# 3             John flung a frisbee to Mary because  0.533531  0.466469
# 4   John forwarded a gossipy email to Mary because  0.603539  0.396462
# 5              John gave a sweater to Mary because  0.482930  0.517070
# 6               John handed a book to Mary because  0.472377  0.527623
# 7        John kicked a soccer ball to Mary because  0.320234  0.679766
# 8           John lobbed a football to Mary because  0.345912  0.654088
# 9             John mailed a letter to Mary because  0.633773  0.366227
# 10          John passed a sandwich to Mary because  0.555844  0.444156
# 11         John rolled a toy truck to Mary because  0.557095  0.442905
# 12           John sent a fruitcake to Mary because  0.449256  0.550744
# 13               John served chili to Mary because  0.452466  0.547534
# 14          John shipped a package to Mary because  0.476419  0.523581
# 15                John threw a hat to Mary because  0.487730  0.512270
# 16        John tossed a dish towel to Mary because  0.495634  0.504366
# 17      John transmitted a message to Mary because  0.647349  0.352651
# 18                John wired money to Mary because  0.607692  0.392307
# 19   Mary brought a glass of water to John because  0.384893  0.615107
# 20             Mary carried a tray to John because  0.231785  0.768215
# 21       Mary delivered a subpoena to John because  0.453402  0.546598
# 22            Mary flung a frisbee to John because  0.543112  0.456888
# 23  Mary forwarded a gossipy email to John because  0.390610  0.609390
# 24             Mary gave a sweater to John because  0.447193  0.552807
# 25              Mary handed a book to John because  0.357402  0.642598
# 26       Mary kicked a soccer ball to John because  0.634273  0.365727
# 27          Mary lobbed a football to John because  0.638726  0.361274
# 28            Mary mailed a letter to John because  0.230193  0.769807
# 29          Mary passed a sandwich to John because  0.546329  0.453671
# 30         Mary rolled a toy truck to John because  0.167904  0.832096
# 31           Mary sent a fruitcake to John because  0.432608  0.567392
# 32               Mary served chili to John because  0.371831  0.628169
# 33          Mary shipped a package to John because  0.416979  0.583021
# 34                Mary threw a hat to John because  0.547616  0.452384
# 35        Mary tossed a dish towel to John because  0.623854  0.376146
# 36      Mary transmitted a message to John because  0.256652  0.743348
# 37                Mary wired money to John because  0.597424  0.402576

# %%
print("P('he'|subj=John)", compute_average(asp_perfective_connective1,"he",0,19))
print("P('she'|subj=John)", compute_average(asp_perfective_connective1,"she",0,19))
# Out:
# P('he'|subj=John) 0.5092341790073797
# P('she'|subj=John) 0.4907658194240771

# %%
print("P('she'|subj=Mary)",compute_average(asp_perfective_connective1,"she",19,38))
print("P('he'|subj=Mary)",compute_average(asp_perfective_connective1,"he",19,38))
# Out:
# P('she'|subj=Mary) 0.5645902172515267
# P('he'|subj=Mary) 0.43540979294400467

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
asp_perfective_connective2 = pd.read_csv("../results/v1.2/exp1A_aspect_perfective_connective2.csv")
asp_perfective_connective2 = asp_perfective_connective2.sort_values(by='Stimuli').reset_index(drop=True)
asp_perfective_connective2
# Out:
#                                               Stimuli        he       she
# 0   John brought a glass of water to Mary and, as ...  0.270520  0.729480
# 1       John carried a tray to Mary and, as a result,  0.403546  0.596454
# 2   John delivered a subpoena to Mary and, as a re...  0.251435  0.748565
# 3      John flung a frisbee to Mary and, as a result,  0.216912  0.783088
# 4   John forwarded a gossipy email to Mary and, as...  0.172086  0.827914
# 5       John gave a sweater to Mary and, as a result,  0.245645  0.754355
# 6        John handed a book to Mary and, as a result,  0.129652  0.870348
# 7   John kicked a soccer ball to Mary and, as a re...  0.385462  0.614538
# 8    John lobbed a football to Mary and, as a result,  0.188639  0.811361
# 9      John mailed a letter to Mary and, as a result,  0.180134  0.819866
# 10   John passed a sandwich to Mary and, as a result,  0.294818  0.705182
# 11  John rolled a toy truck to Mary and, as a result,  0.425336  0.574664
# 12    John sent a fruitcake to Mary and, as a result,  0.082669  0.917331
# 13        John served chili to Mary and, as a result,  0.269125  0.730875
# 14   John shipped a package to Mary and, as a result,  0.262930  0.737070
# 15         John threw a hat to Mary and, as a result,  0.294852  0.705148
# 16  John tossed a dish towel to Mary and, as a res...  0.251766  0.748234
# 17  John transmitted a message to Mary and, as a r...  0.119441  0.880559
# 18         John wired money to Mary and, as a result,  0.172808  0.827192
# 19  Mary brought a glass of water to John and, as ...  0.834973  0.165027
# 20      Mary carried a tray to John and, as a result,  0.456941  0.543059
# 21  Mary delivered a subpoena to John and, as a re...  0.607925  0.392075
# 22     Mary flung a frisbee to John and, as a result,  0.837304  0.162696
# 23  Mary forwarded a gossipy email to John and, as...  0.708018  0.291982
# 24      Mary gave a sweater to John and, as a result,  0.800737  0.199263
# 25       Mary handed a book to John and, as a result,  0.730306  0.269694
# 26  Mary kicked a soccer ball to John and, as a re...  0.782596  0.217404
# 27   Mary lobbed a football to John and, as a result,  0.822525  0.177475
# 28     Mary mailed a letter to John and, as a result,  0.756722  0.243278
# 29   Mary passed a sandwich to John and, as a result,  0.706680  0.293320
# 30  Mary rolled a toy truck to John and, as a result,  0.584923  0.415077
# 31    Mary sent a fruitcake to John and, as a result,  0.846578  0.153422
# 32        Mary served chili to John and, as a result,  0.648322  0.351678
# 33   Mary shipped a package to John and, as a result,  0.677306  0.322694
# 34         Mary threw a hat to John and, as a result,  0.672393  0.327607
# 35  Mary tossed a dish towel to John and, as a res...  0.844312  0.155688
# 36  Mary transmitted a message to John and, as a r...  0.846832  0.153168
# 37         Mary wired money to John and, as a result,  0.937134  0.062866

# %%
print("P('he'|subj=John)", compute_average(asp_perfective_connective2,"he",0,19))
print("P('she'|subj=John)", compute_average(asp_perfective_connective2,"she",0,19))
# Out:
# P('he'|subj=John) 0.2430409149904
# P('she'|subj=John) 0.7569590932444522

# %%
print("P('she'|subj=Mary)",compute_average(asp_perfective_connective2,"she",19,38))
print("P('he'|subj=Mary)",compute_average(asp_perfective_connective2,"he",19,38))
# Out:
# P('she'|subj=Mary) 0.25776179566195134
# P('he'|subj=Mary) 0.7422381937503815

# %% [markdown]
# ## Stimuli with imperfective transfer of possession verbs

# %% [markdown]
# #### Stimuli with no prompt

# %%
asp_imperfective_noprompt = pd.read_csv("../results/v1.2/exp1A_aspect_imperfective.csv")
asp_imperfective_noprompt = asp_imperfective_noprompt.sort_values(by='Stimuli').reset_index(drop=True)
asp_imperfective_noprompt
# Out:
#                                         Stimuli        He       She
# 0   John was bringing a glass of water to Mary.  0.801113  0.198887
# 1             John was carrying a tray to Mary.  0.784197  0.215803
# 2       John was delivering a subpoena to Mary.  0.787399  0.212601
# 3          John was flinging a frisbee to Mary.  0.784149  0.215851
# 4            John was giving a sweater to Mary.  0.788138  0.211862
# 5              John was handing a book to Mary.  0.782817  0.217183
# 6       John was kicking a soccer ball to Mary.  0.791109  0.208891
# 7          John was lobbing a football to Mary.  0.786062  0.213938
# 8            John was mailing a letter to Mary.  0.789259  0.210741
# 9          John was passing a sandwich to Mary.  0.794699  0.205301
# 10        John was rolling a toy truck to Mary.  0.788757  0.211243
# 11        John was sending a fruitcake to Mary.  0.775906  0.224094
# 12              John was serving chili to Mary.  0.778784  0.221216
# 13         John was shipping a package to Mary.  0.767021  0.232979
# 14             John was throwing a hat to Mary.  0.785616  0.214384
# 15       John was tossing a dish towel to Mary.  0.793270  0.206730
# 16     John was transmitting a message to Mary.  0.780520  0.219480
# 17               John was wiring money to Mary.  0.784941  0.215059
# 18  Mary was bringing a glass of water to John.  0.728925  0.271075
# 19            Mary was carrying a tray to John.  0.733022  0.266978
# 20      Mary was delivering a subpoena to John.  0.154467  0.845533
# 21         Mary was flinging a frisbee to John.  0.737032  0.262968
# 22           Mary was giving a sweater to John.  0.229357  0.770643
# 23             Mary was handing a book to John.  0.376612  0.623388
# 24      Mary was kicking a soccer ball to John.  0.733790  0.266210
# 25         Mary was lobbing a football to John.  0.740055  0.259945
# 26           Mary was mailing a letter to John.  0.189395  0.810605
# 27         Mary was passing a sandwich to John.  0.728883  0.271117
# 28        Mary was rolling a toy truck to John.  0.731444  0.268556
# 29        Mary was sending a fruitcake to John.  0.717340  0.282660
# 30              Mary was serving chili to John.  0.729461  0.270539
# 31         Mary was shipping a package to John.  0.702522  0.297479
# 32             Mary was throwing a hat to John.  0.734429  0.265571
# 33       Mary was tossing a dish towel to John.  0.739215  0.260785
# 34     Mary was transmitting a message to John.  0.304355  0.695645
# 35               Mary was wiring money to John.  0.217256  0.782744

# %%
print("P('He'|subj=John)", compute_average(asp_imperfective_noprompt,"He",0,19))
print("P('She'|subj=John)", compute_average(asp_imperfective_noprompt,"She",0,19))
# Out:
# P('He'|subj=John) 0.782772632021653
# P('She'|subj=John) 0.2172273609199022

# %%
print("P('She'|subj=Mary)",compute_average(asp_imperfective_noprompt,"She",19,38))
print("P('He'|subj=Mary)",compute_average(asp_imperfective_noprompt,"He",19,38))
# Out:
# P('She'|subj=Mary) 0.44125671246472525
# P('He'|subj=Mary) 0.5587432945475859

# %% [markdown]
# #### Stimuli with connective: "because"

# %%
asp_imperfective_connective1 = pd.read_csv("../results/v1.2/exp1A_aspect_imperfective_connective1.csv")
asp_imperfective_connective1 = asp_imperfective_connective1.sort_values(by='Stimuli').reset_index(drop=True)
asp_imperfective_connective1
# Out:
#                                               Stimuli        he       she
# 0   John was bringing a glass of water to Mary bec...  0.458247  0.541753
# 1            John was carrying a tray to Mary because  0.626296  0.373704
# 2      John was delivering a subpoena to Mary because  0.549737  0.450263
# 3         John was flinging a frisbee to Mary because  0.578134  0.421866
# 4           John was giving a sweater to Mary because  0.504957  0.495043
# 5             John was handing a book to Mary because  0.548124  0.451876
# 6      John was kicking a soccer ball to Mary because  0.464612  0.535388
# 7         John was lobbing a football to Mary because  0.436587  0.563413
# 8           John was mailing a letter to Mary because  0.711032  0.288968
# 9         John was passing a sandwich to Mary because  0.656146  0.343854
# 10       John was rolling a toy truck to Mary because  0.596306  0.403694
# 11       John was sending a fruitcake to Mary because  0.483039  0.516961
# 12             John was serving chili to Mary because  0.496251  0.503749
# 13        John was shipping a package to Mary because  0.552817  0.447183
# 14            John was throwing a hat to Mary because  0.552867  0.447133
# 15      John was tossing a dish towel to Mary because  0.535316  0.464684
# 16    John was transmitting a message to Mary because  0.677544  0.322456
# 17              John was wiring money to Mary because  0.660992  0.339008
# 18  Mary was bringing a glass of water to John bec...  0.534684  0.465316
# 19           Mary was carrying a tray to John because  0.239227  0.760773
# 20     Mary was delivering a subpoena to John because  0.451837  0.548163
# 21        Mary was flinging a frisbee to John because  0.533122  0.466878
# 22          Mary was giving a sweater to John because  0.433571  0.566429
# 23            Mary was handing a book to John because  0.373004  0.626996
# 24     Mary was kicking a soccer ball to John because  0.504683  0.495317
# 25        Mary was lobbing a football to John because  0.601524  0.398476
# 26          Mary was mailing a letter to John because  0.217100  0.782900
# 27        Mary was passing a sandwich to John because  0.551821  0.448179
# 28       Mary was rolling a toy truck to John because  0.272508  0.727491
# 29       Mary was sending a fruitcake to John because  0.474923  0.525077
# 30             Mary was serving chili to John because  0.341422  0.658578
# 31        Mary was shipping a package to John because  0.439882  0.560118
# 32            Mary was throwing a hat to John because  0.581366  0.418634
# 33      Mary was tossing a dish towel to John because  0.624381  0.375619
# 34    Mary was transmitting a message to John because  0.231656  0.768343
# 35              Mary was wiring money to John because  0.211365  0.788635

# %%
print("P('He'|subj=John)", compute_average(asp_imperfective_connective1,"he",0,19))
print("P('She'|subj=John)", compute_average(asp_imperfective_connective1,"she",0,19))
# Out:
# P('He'|subj=John) 0.5591413927705664
# P('She'|subj=John) 0.4408586135036067

# %%
print("P('She'|subj=Mary)",compute_average(asp_imperfective_connective1,"she",19,38))
print("P('He'|subj=Mary)",compute_average(asp_imperfective_connective1,"he",19,38))
# Out:
# P('She'|subj=Mary) 0.5833298563957214
# P('He'|subj=Mary) 0.4166701374685063

# %% [markdown]
# #### Stimuli with connective phrase: "and, as a result,"

# %%
asp_imperfective_connective2 = pd.read_csv("../results/v1.2/exp1A_aspect_imperfective_connective2.csv")
asp_imperfective_connective2 = asp_imperfective_connective2.sort_values(by='Stimuli').reset_index(drop=True)
asp_imperfective_connective2
# Out:
#                                               Stimuli        he       she
# 0   John was bringing a glass of water to Mary and...  0.321944  0.678056
# 1   John was carrying a tray to Mary and, as a res...  0.614483  0.385517
# 2   John was delivering a subpoena to Mary and, as...  0.436703  0.563297
# 3   John was flinging a frisbee to Mary and, as a ...  0.389127  0.610873
# 4   John was giving a sweater to Mary and, as a re...  0.467356  0.532645
# 5   John was handing a book to Mary and, as a result,  0.360734  0.639266
# 6   John was kicking a soccer ball to Mary and, as...  0.601093  0.398907
# 7   John was lobbing a football to Mary and, as a ...  0.408210  0.591790
# 8   John was mailing a letter to Mary and, as a re...  0.370414  0.629586
# 9   John was passing a sandwich to Mary and, as a ...  0.366779  0.633221
# 10  John was rolling a toy truck to Mary and, as a...  0.600329  0.399671
# 11  John was sending a fruitcake to Mary and, as a...  0.200603  0.799397
# 12   John was serving chili to Mary and, as a result,  0.545168  0.454832
# 13  John was shipping a package to Mary and, as a ...  0.533720  0.466280
# 14  John was throwing a hat to Mary and, as a result,  0.433150  0.566850
# 15  John was tossing a dish towel to Mary and, as ...  0.379415  0.620585
# 16  John was transmitting a message to Mary and, a...  0.215138  0.784862
# 17    John was wiring money to Mary and, as a result,  0.510658  0.489342
# 18  Mary was bringing a glass of water to John and...  0.708713  0.291287
# 19  Mary was carrying a tray to John and, as a res...  0.300235  0.699765
# 20  Mary was delivering a subpoena to John and, as...  0.470356  0.529644
# 21  Mary was flinging a frisbee to John and, as a ...  0.629503  0.370497
# 22  Mary was giving a sweater to John and, as a re...  0.503294  0.496706
# 23  Mary was handing a book to John and, as a result,  0.555430  0.444570
# 24  Mary was kicking a soccer ball to John and, as...  0.591103  0.408897
# 25  Mary was lobbing a football to John and, as a ...  0.563150  0.436850
# 26  Mary was mailing a letter to John and, as a re...  0.598264  0.401736
# 27  Mary was passing a sandwich to John and, as a ...  0.678221  0.321779
# 28  Mary was rolling a toy truck to John and, as a...  0.514446  0.485553
# 29  Mary was sending a fruitcake to John and, as a...  0.644047  0.355953
# 30   Mary was serving chili to John and, as a result,  0.425036  0.574964
# 31  Mary was shipping a package to John and, as a ...  0.404541  0.595459
# 32  Mary was throwing a hat to John and, as a result,  0.506801  0.493199
# 33  Mary was tossing a dish towel to John and, as ...  0.750342  0.249658
# 34  Mary was transmitting a message to John and, a...  0.692508  0.307492
# 35    Mary was wiring money to John and, as a result,  0.571328  0.428672

# %%
print("P('He'|subj=John)", compute_average(asp_imperfective_connective2,"he",0,19))
print("P('She'|subj=John)", compute_average(asp_imperfective_connective2,"she",0,19))
# Out:
# P('He'|subj=John) 0.4454599783608788
# P('She'|subj=John) 0.554540028697566

# %%
print("P('She'|subj=Mary)",compute_average(asp_imperfective_connective2,"she",19,38))
print("P('He'|subj=Mary)",compute_average(asp_imperfective_connective2,"he",19,38))
# Out:
# P('She'|subj=Mary) 0.4471408794907963
# P('He'|subj=Mary) 0.5528591222622815
